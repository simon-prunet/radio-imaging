# %% [markdown]
# # Notebook for visualizing parallelized method for more than two partitions
# For the time being only as a function of major cycles until I get proper timing results, the full dataset settings can be found in their config files

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy
import os
import logging, sys
import math

from radioimaging.util import util
from radioimaging.evaluation import evaluation

matplotlib.rcParams['figure.figsize'] = [6, 5]

cmap = "turbo"

breakdowns = [
    "read",
    "grid",
    "degrid",
    "deconvolve",
    "other"
]

breakdowns_parallel = [
    "read",
    "grid",
    "degrid",
    "deconvolve",
    "wait",
    "other"
]

num_mc_l1 = 5
num_mc_msc = 10

def total_timings(timings, breakdowns):
    total = []
    
    for i, breakdown in enumerate(breakdowns):
        curr_timing = 0

        for timing in timings:
            curr_timing += timing[i]

        total.append(curr_timing)
        
    return total

pcols = ["forestgreen", "teal", "mediumblue", "blueviolet", "fuchsia"]
# Out:
# /usr/lib/python3.10/abc.py:106: FutureWarning: xarray subclass Visibility should explicitly define __slots__
#   cls = super().__new__(mcls, name, bases, namespace, **kwargs)

# %% [markdown]
# ## Sgr A
#
# $\ell$ = [3, 10, 35, 70]
#
# $\delta$ = 1

# %%
sgra_res_path = "../results/multipartition_results/SGRA/"

pl1_breakdown_data = []
pmsc_breakdown_data = []

partitions=["<4", "2-11", "9-36", "34-71", ">69"]
num_partitions = len(partitions)

for i in range(num_partitions):
    pl1_breakdown_data.append(util.read_csv(sgra_res_path + "SGRA_pl1/mc_timings_breakdown_" + str(i), separate_rows=True))

for i in range(num_partitions):
    pmsc_breakdown_data.append(util.read_csv(sgra_res_path + "SGRA_pmsc/mc_timings_breakdown_" + str(i), separate_rows=True))
    
serial_breakdown_data = util.read_csv(sgra_res_path + "SGRA_seriall1/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = util.read_csv(sgra_res_path + "SGRA_serialmsc/mc_timings_breakdown", separate_rows=True)

dirty = util.fromfits(sgra_res_path + "SGRA_seriall1/residual_0.fits")
util.plotNImages([dirty], [""], cmap="turbo", hide_ticks=True)

# %% [markdown]
# ### L1

# %%
serial_times_sep = util.read_csv(sgra_res_path + "SGRA_seriall1/mc_timings")
serial_times = []
serial_snrs = []

parallel_times_sep = util.read_csv(sgra_res_path + "SGRA_pl1/mc_timings")
parallel_times = []
parallel_snrs = []
combined_snrs = []

best_parallel_recon = None
best_serial_recon = None
best_parallel_snr = -9999
best_serial_snr = -9999

gt = util.fromfits("../data7/SGRA_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_snrs.append(0)

for i in range(0, num_mc_l1):
    curr_deconv_img = util.fromfits(sgra_res_path + "SGRA_seriall1/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])
    
    serial_snrs.append(evaluation.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
    if best_serial_snr < serial_snrs[-1]:
        best_serial_recon = curr_deconv.copy()
        best_serial_snr = serial_snrs[-1]
    
    
#parallel
curr_deconvs = [None for i in range(num_partitions)]
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
for i in range(num_partitions):
    parallel_snrs.append([0])

combined_snrs.append(0)

for i in range(0, num_mc_l1):
    for j in range(num_partitions):
        curr_deconv = util.fromfits(sgra_res_path + "SGRA_pl1/deconv_" + str(j) + "_" + str(i) + ".fits")
        if curr_deconvs[j] is None:
            curr_deconvs[j] = curr_deconv
        else:
            curr_deconvs[j] += curr_deconv
            
        parallel_snrs[j].append(evaluation.compute_snr(curr_deconvs[j], gt))

    time_acc += float(parallel_times_sep[i+1])

    curr_deconv_combined = util.fromfits(sgra_res_path + "SGRA_pl1/recon_combined_" + str(i) + ".fits")
    combined_snrs.append(evaluation.compute_snr(curr_deconv_combined, gt))
    
    parallel_times.append(time_acc)
    
    if best_parallel_snr < combined_snrs[-1]:
        best_parallel_recon = curr_deconv_combined.copy()
        best_parallel_snr = combined_snrs[-1]
    
for i, p_snrs in enumerate(parallel_snrs):
    plt.plot(parallel_times, parallel_snrs[i], c=pcols[i], lw=3, alpha=0.1, marker='o', markersize=5)
    
plt.plot(serial_times, serial_snrs, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
plt.plot(parallel_times, combined_snrs, c='coral', label="p-$L1$", lw=3, marker='o', markersize=10)



plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgra_multipartition_l1_timeacc.png", pad_inches=0.0, bbox_inches='tight')

plt.show()

util.plotNImages([best_serial_recon, best_parallel_recon], ["Serial", "Parallel"], same_scale=True, cmap=cmap)
util.plotNImages([numpy.abs(gt - best_serial_recon), numpy.abs(gt - best_parallel_recon)], \
                    ["Serial abs err", "Parallel abs err"], same_scale=True, cmap=cmap)

# %%
#Serial l1

for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

average_deconv = 0

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %%
#Parallel l1

sgra_pl1_timings = []

for pl1_node in pl1_breakdown_data:
    breakdown_data = []
    for i, lst in enumerate(pl1_node):
        breakdown_data.append(list(map(float, lst)))
    
    weights_timings = breakdown_data[1]
    psf_timings = breakdown_data[2]
    wait_timings = breakdown_data[3]
    mc_timings = breakdown_data[4:]
    
    width = 0.5
    
    labels = [
        "Weights",
        "PSF"
    ]
        
    bottom = numpy.zeros(len(mc_timings) + 2)
        
    fig, ax = plt.subplots()
    
    timings = []
    timings.append([weights_timings[0], 0, 0, 0, 0, sum(weights_timings[1:])])
    timings.append([psf_timings[0], psf_timings[3], 0, 0, 0, sum(psf_timings[1:2]) + psf_timings[4]])
    
    for i, curr_mc_timings in enumerate(mc_timings):
        labels.append("MC " + str(i))
        other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
        timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                        curr_mc_timings[0] + curr_mc_timings[10], other_timings])
        
    for i, curr_breakdown in enumerate(breakdowns_parallel):
        curr_breakdown_timing = []
        for curr_timing in timings:
            curr_breakdown_timing.append(curr_timing[i])
    
        p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
        bottom += curr_breakdown_timing
        
    sgra_pl1_timings.append(total_timings(timings, breakdowns_parallel))
        
    ax.legend(loc="upper right")
    plt.show()

# %% [markdown]
# ### ms-CLEAN

# %%
serial_times_sep = util.read_csv(sgra_res_path + "SGRA_serialmsc/mc_timings")
serial_times = []
serial_snrs = []

parallel_times_sep = util.read_csv(sgra_res_path + "SGRA_pmsc/mc_timings")
parallel_times = []
parallel_snrs = []
combined_snrs = []

best_parallel_recon = None
best_serial_recon = None
best_parallel_snr = -9999
best_serial_snr = -9999

gt = util.fromfits("../data7/SGRA_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_snrs.append(0)

for i in range(0, num_mc_msc):
    curr_deconv_img = util.fromfits(sgra_res_path + "SGRA_serialmsc/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])
    
    serial_snrs.append(evaluation.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
    if best_serial_snr < serial_snrs[-1]:
        best_serial_recon = curr_deconv.copy()
        best_serial_snr = serial_snrs[-1]
    
    
#parallel
curr_deconvs = [None for i in range(num_partitions)]
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
for i in range(num_partitions):
    parallel_snrs.append([0])

combined_snrs.append(0)

for i in range(0, num_mc_msc):
    for j in range(num_partitions):
        curr_deconv = util.fromfits(sgra_res_path + "SGRA_pmsc/deconv_" + str(j) + "_" + str(i) + ".fits")
        if curr_deconvs[j] is None:
            curr_deconvs[j] = curr_deconv
        else:
            curr_deconvs[j] += curr_deconv
            
        parallel_snrs[j].append(evaluation.compute_snr(curr_deconvs[j], gt))

    time_acc += float(parallel_times_sep[i+1])

    curr_deconv_combined = util.fromfits(sgra_res_path + "SGRA_pmsc/recon_combined_" + str(i) + ".fits")
    combined_snrs.append(evaluation.compute_snr(curr_deconv_combined, gt))
    
    parallel_times.append(time_acc)
    
    if best_parallel_snr < combined_snrs[-1]:
        best_parallel_recon = curr_deconv_combined.copy()
        best_parallel_snr = combined_snrs[-1]
    
for i, p_snrs in enumerate(parallel_snrs):
    plt.plot(parallel_times, parallel_snrs[i], c=pcols[i], lw=3, alpha=0.1, marker='o', markersize=5)
    
plt.plot(serial_times, serial_snrs, c='darkblue', label="msc", lw=3, marker='o', markersize=10)
plt.plot(parallel_times, combined_snrs, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)



plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgra_multipartition_msc_timeacc.png", pad_inches=0.0, bbox_inches='tight')

#plt.show()

util.plotNImages([best_serial_recon, best_parallel_recon], ["Serial", "Parallel"], same_scale=True, cmap=cmap)
util.plotNImages([numpy.abs(gt - best_serial_recon), numpy.abs(gt - best_parallel_recon)], \
                    ["Serial abs err", "Parallel abs err"], same_scale=True, cmap=cmap)

# %%
#serial msc

for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %%
#Parallel msc

sgra_pmsc_timings = []

for pmsc_node in pmsc_breakdown_data:
    breakdown_data = []
    for i, lst in enumerate(pmsc_node):
        breakdown_data.append(list(map(float, lst)))
    
    weights_timings = breakdown_data[1]
    psf_timings = breakdown_data[2]
    wait_timings = breakdown_data[3] + breakdown_data[4]
    mc_timings = breakdown_data[5:]

    width = 0.5
    
    labels = [
        "Weights",
        "PSF"
    ]
        
    bottom = numpy.zeros(len(mc_timings) + 2)
        
    fig, ax = plt.subplots()
    
    timings = []
    timings.append([weights_timings[0], 0, 0, 0, 0, sum(weights_timings[1:])])
    timings.append([psf_timings[0], psf_timings[3], 0, 0, 0, sum(psf_timings[1:2]) + psf_timings[4]])
    
    for i, curr_mc_timings in enumerate(mc_timings):
        labels.append("MC " + str(i))
        other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
        timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], \
                        curr_mc_timings[9] + curr_mc_timings[10], other_timings])
        
    for i, curr_breakdown in enumerate(breakdowns_parallel):
        curr_breakdown_timing = []
        for curr_timing in timings:
            curr_breakdown_timing.append(curr_timing[i])
    
        p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
        bottom += curr_breakdown_timing
        
    sgra_pmsc_timings.append(total_timings(timings, breakdowns_parallel))
        
    ax.legend(loc="upper right")
    plt.show()

# %% [markdown]
# ## Sgr B2
#
# $\ell$ = [3, 10, 35, 70]
#
# $\delta$ = 1

# %%
sgrb_res_path = "../results/multipartition_results/SGRB/"

breakdown_data = []

partitions=["<4", "2-11", "9-36", "34-71", ">69"]
num_partitions = len(partitions)

for i in range(num_partitions):
    breakdown_data.append(util.read_csv(sgrb_res_path + "SGRB_pl1/mc_timings_breakdown_" + str(i), separate_rows=True))

for i in range(num_partitions):
    breakdown_data.append(util.read_csv(sgrb_res_path + "SGRB_pmsc/mc_timings_breakdown_" + str(i), separate_rows=True))
    
serial_breakdown_data = util.read_csv(sgrb_res_path + "SGRB_seriall1/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = util.read_csv(sgrb_res_path + "SGRB_serialmsc/mc_timings_breakdown", separate_rows=True)

dirty = util.fromfits(sgrb_res_path + "SGRB_seriall1/residual_0.fits")
util.plotNImages([dirty], [""], cmap="turbo", hide_ticks=True)

# %% [markdown]
# ### L1

# %%
serial_times_sep = util.read_csv(sgrb_res_path + "SGRB_seriall1/mc_timings")
serial_times = []
serial_snrs = []

parallel_times_sep = util.read_csv(sgrb_res_path + "SGRB_pl1/mc_timings")
parallel_times = []
parallel_snrs = []
combined_snrs = []


gt = util.fromfits("../data7/SGRB_full_gt.fits")

best_parallel_recon = None
best_serial_recon = None
best_parallel_snr = -9999
best_serial_snr = -9999

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_snrs.append(0)

for i in range(0, num_mc_l1):
    curr_deconv_img = util.fromfits(sgrb_res_path + "SGRB_seriall1/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])
    
    serial_snrs.append(evaluation.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
    if best_serial_snr < serial_snrs[-1]:
        best_serial_recon = curr_deconv.copy()
        best_serial_snr = serial_snrs[-1]
    
    
#parallel
curr_deconvs = [None for i in range(num_partitions)]
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
for i in range(num_partitions):
    parallel_snrs.append([0])

combined_snrs.append(0)

for i in range(0, num_mc_l1):
    for j in range(num_partitions):
        curr_deconv = util.fromfits(sgrb_res_path + "SGRB_pl1/deconv_" + str(j) + "_" + str(i) + ".fits")
        if curr_deconvs[j] is None:
            curr_deconvs[j] = curr_deconv
        else:
            curr_deconvs[j] += curr_deconv
            
        parallel_snrs[j].append(evaluation.compute_snr(curr_deconvs[j], gt))

    time_acc += float(parallel_times_sep[i+1])

    curr_deconv_combined = util.fromfits(sgrb_res_path + "SGRB_pl1/recon_combined_" + str(i) + ".fits")
    combined_snrs.append(evaluation.compute_snr(curr_deconv_combined, gt))
    
    parallel_times.append(time_acc)
    
    if best_parallel_snr < combined_snrs[-1]:
        best_parallel_recon = curr_deconv_combined.copy()
        best_parallel_snr = combined_snrs[-1]
    
for i, p_snrs in enumerate(parallel_snrs):
    plt.plot(parallel_times, parallel_snrs[i], c=pcols[i], lw=3, alpha=0.1, marker='o', markersize=5)
    
plt.plot(serial_times, serial_snrs, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
plt.plot(parallel_times, combined_snrs, c='coral', label="p-$L1$", lw=3, marker='o', markersize=10)



plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrb_multipartition_l1_timeacc.png", pad_inches=0.0, bbox_inches='tight')

#plt.show()

util.plotNImages([best_serial_recon, best_parallel_recon], ["Serial", "Parallel"], same_scale=True, cmap=cmap)
util.plotNImages([numpy.abs(gt - best_serial_recon), numpy.abs(gt - best_parallel_recon)], \
                    ["Serial abs err", "Parallel abs err"], same_scale=True, cmap=cmap)

print(serial_times[-1])
print(parallel_times[-1])
# Out:
# 726.6574556827545
# 462.456111907959

# %%
#Serial l1

for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

average_deconv = 0

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %%
#Parallel l1

sgrb_pl1_timings = []

for pl1_node in pl1_breakdown_data:
    breakdown_data = []
    for i, lst in enumerate(pl1_node):
        breakdown_data.append(list(map(float, lst)))
    
    weights_timings = breakdown_data[1]
    psf_timings = breakdown_data[2]
    wait_timings = breakdown_data[3]
    mc_timings = breakdown_data[4:]
    
    width = 0.5
    
    labels = [
        "Weights",
        "PSF"
    ]
        
    bottom = numpy.zeros(len(mc_timings) + 2)
        
    fig, ax = plt.subplots()
    
    timings = []
    timings.append([weights_timings[0], 0, 0, 0, 0, sum(weights_timings[1:])])
    timings.append([psf_timings[0], psf_timings[3], 0, 0, 0, sum(psf_timings[1:2]) + psf_timings[4]])
    
    for i, curr_mc_timings in enumerate(mc_timings):
        labels.append("MC " + str(i))
        other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
        timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                        curr_mc_timings[0] + curr_mc_timings[10], other_timings])
        
    for i, curr_breakdown in enumerate(breakdowns_parallel):
        curr_breakdown_timing = []
        for curr_timing in timings:
            curr_breakdown_timing.append(curr_timing[i])
    
        p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
        bottom += curr_breakdown_timing
        
    sgrb_pl1_timings.append(total_timings(timings, breakdowns_parallel))
        
    ax.legend(loc="upper right")
    plt.show()

# %%
serial_times_sep = util.read_csv(sgrb_res_path + "SGRB_serialmsc/mc_timings")
serial_times = []
serial_snrs = []

parallel_times_sep = util.read_csv(sgrb_res_path + "SGRB_pmsc/mc_timings")
parallel_times = []
parallel_snrs = []
combined_snrs = []

best_parallel_recon = None
best_serial_recon = None
best_parallel_snr = -9999
best_serial_snr = -9999

gt = util.fromfits("../data7/SGRB_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_snrs.append(0)

for i in range(0, num_mc_msc):
    curr_deconv_img = util.fromfits(sgrb_res_path + "SGRB_serialmsc/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])
    
    serial_snrs.append(evaluation.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
    if best_serial_snr < serial_snrs[-1]:
        best_serial_recon = curr_deconv.copy()
        best_serial_snr = serial_snrs[-1]
    
    
#parallel
curr_deconvs = [None for i in range(num_partitions)]
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
for i in range(num_partitions):
    parallel_snrs.append([0])

combined_snrs.append(0)

for i in range(0, num_mc_msc):
    for j in range(num_partitions):
        curr_deconv = util.fromfits(sgrb_res_path + "SGRB_pmsc/deconv_" + str(j) + "_" + str(i) + ".fits")
        if curr_deconvs[j] is None:
            curr_deconvs[j] = curr_deconv
        else:
            curr_deconvs[j] += curr_deconv
            
        parallel_snrs[j].append(evaluation.compute_snr(curr_deconvs[j], gt))

    time_acc += float(parallel_times_sep[i+1])

    curr_deconv_combined = util.fromfits(sgrb_res_path + "SGRB_pmsc/recon_combined_" + str(i) + ".fits")
    combined_snrs.append(evaluation.compute_snr(curr_deconv_combined, gt))
    
    parallel_times.append(time_acc)
    
    if best_parallel_snr < combined_snrs[-1]:
        best_parallel_recon = curr_deconv_combined.copy()
        best_parallel_snr = combined_snrs[-1]
    
for i, p_snrs in enumerate(parallel_snrs):
    plt.plot(parallel_times, parallel_snrs[i], c=pcols[i], lw=3, alpha=0.1, marker='o', markersize=5)
    
plt.plot(serial_times, serial_snrs, c='darkblue', label="msc", lw=3, marker='o', markersize=10)
plt.plot(parallel_times, combined_snrs, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)



plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrb_multipartition_msc_timeacc.png", pad_inches=0.0, bbox_inches='tight')

#plt.show()

util.plotNImages([best_serial_recon, best_parallel_recon], ["Serial", "Parallel"], same_scale=True, cmap=cmap)
util.plotNImages([numpy.abs(gt - best_serial_recon), numpy.abs(gt - best_parallel_recon)], \
                    ["Serial abs err", "Parallel abs err"], same_scale=True, cmap=cmap)

print(serial_times[-1])
print(parallel_times[-1])
# Out:
# 1192.2180352210999
# 654.6915504932404

# %%
#serial msc

for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %%
#Parallel msc

sgrb_pmsc_timings = []

for pmsc_node in pmsc_breakdown_data:
    breakdown_data = []
    for i, lst in enumerate(pmsc_node):
        breakdown_data.append(list(map(float, lst)))
    
    weights_timings = breakdown_data[1]
    psf_timings = breakdown_data[2]
    wait_timings = breakdown_data[3] + breakdown_data[4]
    mc_timings = breakdown_data[5:]

    width = 0.5
    
    labels = [
        "Weights",
        "PSF"
    ]
        
    bottom = numpy.zeros(len(mc_timings) + 2)
        
    fig, ax = plt.subplots()
    
    timings = []
    timings.append([weights_timings[0], 0, 0, 0, 0, sum(weights_timings[1:])])
    timings.append([psf_timings[0], psf_timings[3], 0, 0, 0, sum(psf_timings[1:2]) + psf_timings[4]])
    
    for i, curr_mc_timings in enumerate(mc_timings):
        labels.append("MC " + str(i))
        other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
        timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], \
                        curr_mc_timings[9] + curr_mc_timings[10], other_timings])
        
    for i, curr_breakdown in enumerate(breakdowns_parallel):
        curr_breakdown_timing = []
        for curr_timing in timings:
            curr_breakdown_timing.append(curr_timing[i])
    
        p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
        bottom += curr_breakdown_timing
        
    sgrb_pmsc_timings.append(total_timings(timings, breakdowns_parallel))
        
    ax.legend(loc="upper right")
    plt.show()

# %% [markdown]
# ## Sgr C
#
# $\ell$ = [3, 10, 35, 70]
#
# $\delta$ = 1

# %%
sgrc_res_path = "../results/multipartition_results/SGRC/"

breakdown_data = []

partitions=["<4", "2-11", "9-36", "34-71", ">69"]
num_partitions = len(partitions)

for i in range(num_partitions):
    breakdown_data.append(util.read_csv(sgrc_res_path + "SGRC_pl1/mc_timings_breakdown_" + str(i), separate_rows=True))
    
for i in range(num_partitions):
    breakdown_data.append(util.read_csv(sgrc_res_path + "SGRC_pmsc/mc_timings_breakdown_" + str(i), separate_rows=True))
    
serial_breakdown_data = util.read_csv(sgrc_res_path + "SGRC_seriall1/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = util.read_csv(sgrc_res_path + "SGRC_serialmsc/mc_timings_breakdown", separate_rows=True)

dirty = util.fromfits(sgrc_res_path + "SGRC_seriall1/residual_0.fits")
util.plotNImages([dirty], [""], cmap="turbo", hide_ticks=True)

# %%
serial_times_sep = util.read_csv(sgrc_res_path + "SGRC_seriall1/mc_timings")
serial_times = []
serial_snrs = []

parallel_times_sep = util.read_csv(sgrc_res_path + "SGRC_pl1/mc_timings")
parallel_times = []
parallel_snrs = []
combined_snrs = []

best_parallel_recon = None
best_serial_recon = None
best_parallel_snr = -9999
best_serial_snr = -9999

gt = util.fromfits("../data7/SGRC_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_snrs.append(0)

for i in range(0, num_mc_l1):
    curr_deconv_img = util.fromfits(sgrc_res_path + "SGRC_seriall1/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])
    
    serial_snrs.append(evaluation.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
    if best_serial_snr < serial_snrs[-1]:
        best_serial_recon = curr_deconv.copy()
        best_serial_snr = serial_snrs[-1]
    
    
#parallel
curr_deconvs = [None for i in range(num_partitions)]
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
for i in range(num_partitions):
    parallel_snrs.append([0])

combined_snrs.append(0)

for i in range(0, num_mc_l1):
    for j in range(num_partitions):
        curr_deconv = util.fromfits(sgrc_res_path + "SGRC_pl1/deconv_" + str(j) + "_" + str(i) + ".fits")
        if curr_deconvs[j] is None:
            curr_deconvs[j] = curr_deconv
        else:
            curr_deconvs[j] += curr_deconv
            
        parallel_snrs[j].append(evaluation.compute_snr(curr_deconvs[j], gt))

    time_acc += float(parallel_times_sep[i+1])

    curr_deconv_combined = util.fromfits(sgrc_res_path + "SGRC_pl1/recon_combined_" + str(i) + ".fits")
    combined_snrs.append(evaluation.compute_snr(curr_deconv_combined, gt))
    
    parallel_times.append(time_acc)
    
    if best_parallel_snr < combined_snrs[-1]:
        best_parallel_recon = curr_deconv_combined.copy()
        best_parallel_snr = combined_snrs[-1]
    
for i, p_snrs in enumerate(parallel_snrs):
    plt.plot(parallel_times, parallel_snrs[i], c=pcols[i], lw=3, alpha=0.1, marker='o', markersize=5)
    
plt.plot(serial_times, serial_snrs, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
plt.plot(parallel_times, combined_snrs, c='coral', label="p-$L1$", lw=3, marker='o', markersize=10)



plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrc_multipartition_l1_timeacc.png", pad_inches=0.0, bbox_inches='tight')

#plt.show()

util.plotNImages([best_serial_recon, best_parallel_recon], ["Serial", "Parallel"], same_scale=True, cmap=cmap)
util.plotNImages([numpy.abs(gt - best_serial_recon), numpy.abs(gt - best_parallel_recon)], \
                    ["Serial abs err", "Parallel abs err"], same_scale=True, cmap=cmap)

print(serial_times[-1])
print(parallel_times[-1])
# Out:
# 1215.1709113121033
# 514.0234060287476

# %%
#Serial l1

for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

average_deconv = 0

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %%
#Parallel l1

sgrc_pl1_timings = []

for pl1_node in pl1_breakdown_data:
    breakdown_data = []
    for i, lst in enumerate(pl1_node):
        breakdown_data.append(list(map(float, lst)))
    
    weights_timings = breakdown_data[1]
    psf_timings = breakdown_data[2]
    wait_timings = breakdown_data[3]
    mc_timings = breakdown_data[4:]
    
    width = 0.5
    
    labels = [
        "Weights",
        "PSF"
    ]
        
    bottom = numpy.zeros(len(mc_timings) + 2)
        
    fig, ax = plt.subplots()
    
    timings = []
    timings.append([weights_timings[0], 0, 0, 0, 0, sum(weights_timings[1:])])
    timings.append([psf_timings[0], psf_timings[3], 0, 0, 0, sum(psf_timings[1:2]) + psf_timings[4]])
    
    for i, curr_mc_timings in enumerate(mc_timings):
        labels.append("MC " + str(i))
        other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
        timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                        curr_mc_timings[0] + curr_mc_timings[10], other_timings])
        
    for i, curr_breakdown in enumerate(breakdowns_parallel):
        curr_breakdown_timing = []
        for curr_timing in timings:
            curr_breakdown_timing.append(curr_timing[i])
    
        p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
        bottom += curr_breakdown_timing
        
    sgrc_pl1_timings.append(total_timings(timings, breakdowns_parallel))
        
    ax.legend(loc="upper right")
    plt.show()

# %%
serial_times_sep = util.read_csv(sgrc_res_path + "SGRC_serialmsc/mc_timings")
serial_times = []
serial_snrs = []

parallel_times_sep = util.read_csv(sgrc_res_path + "SGRC_pmsc/mc_timings")
parallel_times = []
parallel_snrs = []
combined_snrs = []

gt = util.fromfits("../data7/SGRC_full_gt.fits")

best_parallel_recon = None
best_serial_recon = None
best_parallel_snr = -9999
best_serial_snr = -9999

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_snrs.append(0)

for i in range(0, num_mc_msc):
    curr_deconv_img = util.fromfits(sgrc_res_path + "SGRC_serialmsc/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])
    
    serial_snrs.append(evaluation.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
    if best_serial_snr < serial_snrs[-1]:
        best_serial_recon = curr_deconv.copy()
        best_serial_snr = serial_snrs[-1]
    
    
#parallel
curr_deconvs = [None for i in range(num_partitions)]
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
for i in range(num_partitions):
    parallel_snrs.append([0])

combined_snrs.append(0)

for i in range(0, num_mc_msc):
    for j in range(num_partitions):
        curr_deconv = util.fromfits(sgrc_res_path + "SGRC_pmsc/deconv_" + str(j) + "_" + str(i) + ".fits")
        if curr_deconvs[j] is None:
            curr_deconvs[j] = curr_deconv
        else:
            curr_deconvs[j] += curr_deconv
            
        parallel_snrs[j].append(evaluation.compute_snr(curr_deconvs[j], gt))

    time_acc += float(parallel_times_sep[i+1])

    curr_deconv_combined = util.fromfits(sgrc_res_path + "SGRC_pmsc/recon_combined_" + str(i) + ".fits")
    combined_snrs.append(evaluation.compute_snr(curr_deconv_combined, gt))
    
    parallel_times.append(time_acc)
    
    if best_parallel_snr < combined_snrs[-1]:
        best_parallel_recon = curr_deconv_combined.copy()
        best_parallel_snr = combined_snrs[-1]
    
for i, p_snrs in enumerate(parallel_snrs):
    plt.plot(parallel_times, parallel_snrs[i], c=pcols[i], lw=3, alpha=0.1, marker='o', markersize=5)
    
plt.plot(serial_times, serial_snrs, c='darkblue', label="msc", lw=3, marker='o', markersize=10)
plt.plot(parallel_times, combined_snrs, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)



plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrc_multipartition_msc_timeacc.png", pad_inches=0.0, bbox_inches='tight')

#plt.show()

util.plotNImages([best_serial_recon, best_parallel_recon], ["Serial", "Parallel"], same_scale=True, cmap=cmap)
util.plotNImages([numpy.abs(gt - best_serial_recon), numpy.abs(gt - best_parallel_recon)], \
                    ["Serial abs err", "Parallel abs err"], same_scale=True, cmap=cmap)

print(serial_times[-1])
print(parallel_times[-1])
# Out:
# 1880.87824344635
# 615.987455368042

# %%
#serial msc

for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %%
#Parallel msc

sgrc_pmsc_timings = []

for pmsc_node in pmsc_breakdown_data:
    breakdown_data = []
    for i, lst in enumerate(pmsc_node):
        breakdown_data.append(list(map(float, lst)))
    
    weights_timings = breakdown_data[1]
    psf_timings = breakdown_data[2]
    wait_timings = breakdown_data[3] + breakdown_data[4]
    mc_timings = breakdown_data[5:]

    width = 0.5
    
    labels = [
        "Weights",
        "PSF"
    ]
        
    bottom = numpy.zeros(len(mc_timings) + 2)
        
    fig, ax = plt.subplots()
    
    timings = []
    timings.append([weights_timings[0], 0, 0, 0, 0, sum(weights_timings[1:])])
    timings.append([psf_timings[0], psf_timings[3], 0, 0, 0, sum(psf_timings[1:2]) + psf_timings[4]])
    
    for i, curr_mc_timings in enumerate(mc_timings):
        labels.append("MC " + str(i))
        other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
        timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], \
                        curr_mc_timings[9] + curr_mc_timings[10], other_timings])
        
    for i, curr_breakdown in enumerate(breakdowns_parallel):
        curr_breakdown_timing = []
        for curr_timing in timings:
            curr_breakdown_timing.append(curr_timing[i])
    
        p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
        bottom += curr_breakdown_timing
        
    sgrc_pmsc_timings.append(total_timings(timings, breakdowns_parallel))
        
    ax.legend(loc="upper right")
    plt.show()
