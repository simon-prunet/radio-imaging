# %% [markdown]
# # Results when splitting the real cygnus-a dataset, described in: *A Wideband Polarization Study of Cygnus A with the Jansky Very Large Array. I. The Observations and Data - Sebokolodi et al*

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy
from scipy import signal
import pandas as pd

from rascil.processing_components import create_visibility_from_ms

from radioimaging.util import util
from radioimaging.visibility import residual, weights
from radioimaging.images import images

plt.set_loglevel("critical")
cmap='turbo'
matplotlib.rcParams['figure.figsize'] = [10, 5]

wavelet_type_dict = {"daubechies" : 0, "iuwt" : 1}

wavelet_type = "daubechies"
wavelet_type_idx = wavelet_type_dict[wavelet_type]

runtests = False
niter = 100
# Out:
# /usr/lib/python3.10/abc.py:106: FutureWarning: xarray subclass Visibility should explicitly define __slots__
#   cls = super().__new__(mcls, name, bases, namespace, **kwargs)

# %% [markdown]
# ## PSF and Dirty of split measurement sets cut at $\delta = 5, \ell = 20$
# Just loading precomputed images as loading all visibilities here uses too much memory

# %%
low_dirty = util.fromfits("../data5/cygnusa_smallbaselines_dirty.fits")
low_psf = util.fromfits("../data5/cygnusa_smallbaselines_psf.fits")
high_dirty = util.fromfits("../data5/cygnusa_longbaselines_dirty.fits")
high_psf = util.fromfits("../data5/cygnusa_longbaselines_psf.fits")

util.plotNImages([low_dirty, low_psf], ["Small baselines dirty", "Small baselines psf"], cmap)
util.plotNImages([high_dirty, high_psf], ["Long baselines dirty", "Long baselines psf"], cmap)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 low_dirty = util.fromfits("../data5/cygnusa_smallbaselines_dirty.fits")
#       2 low_psf = util.fromfits("../data5/cygnusa_smallbaselines_psf.fits")
#       3 high_dirty = util.fromfits("../data5/cygnusa_longbaselines_dirty.fits")
#
# File ~/radio-imaging/src/radioimaging/util/util.py:66, in fromfits(filename)
#      59 def fromfits(filename):
#      60     """
#      61     fromfits reads a .fits file to a 2d numpy array. It throws away any additional data if the stored data has more than 2 dimensions
#      62
#      63     :param filename: filename of .fits file
#      64     return: 2d numpy array
#      65     """
# ---> 66     dat = fits.open(filename)[0].data
#      67     while len(dat.shape) > 2:
#      68         dat = dat[0]
#
# File ~/.local/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:223, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     220 if not name:
#     221     raise ValueError(f"Empty filename: {name!r}")
# --> 223 return HDUList.fromfile(
#     224     name,
#     225     mode,
#     226     memmap,
#     227     save_backup,
#     228     cache,
#     229     lazy_load_hdus,
#     230     ignore_missing_simple,
#     231     use_fsspec=use_fsspec,
#     232     fsspec_kwargs=fsspec_kwargs,
#     233     decompress_in_memory=decompress_in_memory,
#     234     **kwargs,
#     235 )
#
# File ~/.local/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:487, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     468 @classmethod
#     469 def fromfile(
#     470     cls,
#    (...)
#     478     **kwargs,
#     479 ):
#     480     """
#     481     Creates an `HDUList` instance from a file-like object.
#     482
#    (...)
#     485     documentation for details of the parameters accepted by this method).
#     486     """
# --> 487     return cls._readfrom(
#     488         fileobj=fileobj,
#     489         mode=mode,
#     490         memmap=memmap,
#     491         save_backup=save_backup,
#     492         cache=cache,
#     493         ignore_missing_simple=ignore_missing_simple,
#     494         lazy_load_hdus=lazy_load_hdus,
#     495         **kwargs,
#     496     )
#
# File ~/.local/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/.local/lib/python3.10/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/.local/lib/python3.10/site-packages/astropy/io/fits/file.py:651, in _File._open_filename(self, filename, mode, overwrite)
#     648 ext = os.path.splitext(self.name)[1]
#     650 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 651     self._file = open(self.name, IO_FITS_MODES[mode])
#     652     self.close_on_error = True
#     654 # Make certain we're back at the beginning of the file
#     655 # BZ2File does not support seek when the file is open for writing, but
#     656 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data5/cygnusa_smallbaselines_dirty.fits'

# %% [markdown]
# ## Simulation results, plotting L2-norm of residual, as well as the error to a finely sampled dirty map, across the major iterations. Algorithm parameters (obtained via trial and error) are as follows:
# #### Small baselines reconstruction: $\lambda = 0.1 \times \|\tilde{\imath}_n\| \times 4^n$
# #### Long baselines reconstruction: $\lambda = 0.02 \times \|\tilde{\imath}_n\| \times 2^n$
# #### Full reconstruction: $\lambda = 0.01 \times \|\tilde{\imath}_n\| \times 2^n$

# %%
nmajor_cyc = 6
path = "../results/cygnus_a/"

data_low = []
data_high = []
data_full = []

residuals_low = []
residuals_high = []
residuals_full = []

curr_deconv_low = None
curr_deconv_high = None

for maj_iter in range(0, nmajor_cyc):
    high_filename = path + "high/dirty_iteration_" + str(maj_iter) + "_channel_0.fits"
    low_filename = path + "low/dirty_iteration_" + str(maj_iter) + "_channel_0.fits"
    full_filename = path + "full/dirty_iteration_" + str(maj_iter) + "_channel_0.fits"
    
    dirty_low = util.fromfits(low_filename)
    dirty_high = util.fromfits(high_filename)
    dirty_full = util.fromfits(full_filename)

    data_low.append(numpy.linalg.norm(dirty_low))
    data_high.append(numpy.linalg.norm(dirty_high))
    data_full.append(numpy.linalg.norm(dirty_full))
    
    residuals_low.append(dirty_low)
    residuals_high.append(dirty_high)
    residuals_full.append(dirty_full)

# %%
plt.plot(range(1, nmajor_cyc + 1), data_low, lw=2)

plt.xlabel("Major Loop Iteration", fontsize=12)
plt.ylabel("$\|\hat{\imath}_\mathcal{L}\|_2$", fontsize=12)
plt.savefig("../figures/low_dirtyl2_cyga.png", bbox_inches='tight')

# %%
plt.plot(range(1, nmajor_cyc + 1), data_high, lw=2)

plt.xlabel("Major Loop Iteration", fontsize=12)
plt.ylabel("$\|\hat{\imath}_\mathcal{H}\|_2$", fontsize=12)
plt.savefig("../figures/high_dirtyl2_cyga.png", bbox_inches='tight')

# %%
plt.plot(range(1, nmajor_cyc + 1), data_full, lw=2)

plt.xlabel("Major Loop Iteration", fontsize=12)
plt.ylabel("$\|\hat{\imath}\|_2$", fontsize=12)
plt.savefig("../figures/full_dirtyl2_cyga.png", bbox_inches='tight')
