# %% [markdown]
# # Per frequency band PSNRs

# %%
import numpy as np
from scipy import signal
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

from radioimaging.util import util
import split

cmap = 'turbo'
# Out:
# /usr/lib/python3.10/abc.py:106: FutureWarning: xarray subclass Visibility should explicitly define __slots__
#   cls = super().__new__(mcls, name, bases, namespace, **kwargs)

# %% [markdown]
# ## Testing bandpass filter

# %%
gt = util.fromfits("../data/SGRA_full_gt.fits")
bpfilter = split.bandpass(gt, 50, 75)
util.plotNImages([bpfilter], ["Bandpass Filter"], cmap=cmap)

# %%
matplotlib.rcParams['figure.figsize'] = [10, 5]

gtfiltered = signal.fftconvolve(gt, bpfilter, mode='same')
util.plotNImages([gt, gtfiltered], ["gt", "bpfiltered 50-75"], cmap=cmap)

# %% [markdown]
# ## Setup bands we will test for

# %%
bands = []
step = 5
for i in range(0, 255, step):
    bands.append((i, i + step - 1))
    
nmaj_iter = 5

colors = plt.cm.viridis(np.linspace(0,1,len(bands)))

# %% [markdown]
# ## Load and compute

# %%
dataset = "SGRA"

gt = util.fromfits("../data/" + dataset + "_full_gt.fits")
lmult = 2
cut = 20
hw = 5
weighting = "uniform"

path = "../results/cut_results/" + dataset + "/" + str(cut) + "/" + str(hw) + "hw/bphigh/lambda_m" + str(lmult)
        
data = split.banded_psnrs(path, gt, bands, nmaj_iter)

data_shifted = []

for x in data:
    firstval = x[1]
    data_shifted.append([val - firstval for val in x[1:]])

# %%
pd.DataFrame(data)
# Out:
#                     0          1          2          3          4          5
# 0       low=0, high=4  13.072164  13.073469  13.073469  13.073469  13.073469
# 1       low=5, high=9  15.217494  15.230572  15.230572  15.230572  15.230572
# 2     low=10, high=14  16.221475  16.325338  16.325338  16.325338  16.325338
# 3     low=15, high=19  10.377112  10.596695  10.596695  10.596695  10.596695
# 4     low=20, high=24   7.317451   7.484218   7.484218   7.484218   7.484218
# 5     low=25, high=29   6.592982   6.771426   6.771426   6.771426   6.771426
# 6     low=30, high=34   5.755779   5.861872   5.861872   5.861872   5.861872
# 7     low=35, high=39   5.422792   5.509086   5.509086   5.509086   5.509086
# 8     low=40, high=44   5.532178   5.630518   5.630518   5.630518   5.630518
# 9     low=45, high=49   5.175708   5.248215   5.248215   5.248215   5.248215
# 10    low=50, high=54   4.532966   4.572881   4.572881   4.572881   4.572881
# 11    low=55, high=59   3.922355   3.988837   3.988837   3.988837   3.988837
# 12    low=60, high=64   4.759918   4.828341   4.828341   4.828341   4.828341
# 13    low=65, high=69   4.884608   4.910661   4.910661   4.910661   4.910661
# 14    low=70, high=74   4.546526   4.573849   4.573849   4.573849   4.573849
# 15    low=75, high=79   4.480791   4.505916   4.505916   4.505916   4.505916
# 16    low=80, high=84   3.595193   3.608643   3.608643   3.608643   3.608643
# 17    low=85, high=89   3.471700   3.470403   3.470403   3.470403   3.470403
# 18    low=90, high=94   3.421181   3.422821   3.422821   3.422821   3.422821
# 19    low=95, high=99   3.525918   3.522371   3.522371   3.522371   3.522371
# 20  low=100, high=104   3.342515   3.339836   3.339836   3.339836   3.339836
# 21  low=105, high=109   3.320712   3.320156   3.320156   3.320156   3.320156
# 22  low=110, high=114   3.101608   3.101882   3.101882   3.101882   3.101882
# 23  low=115, high=119   2.846467   2.853601   2.853601   2.853601   2.853601
# 24  low=120, high=124   2.836757   2.843813   2.843813   2.843813   2.843813
# 25  low=125, high=129   2.717667   2.724044   2.724044   2.724044   2.724044
# 26  low=130, high=134   2.272546   2.276732   2.276732   2.276732   2.276732
# 27  low=135, high=139   2.061374   2.065602   2.065602   2.065602   2.065602
# 28  low=140, high=144   2.093931   2.103781   2.103781   2.103781   2.103781
# 29  low=145, high=149   1.907488   1.915510   1.915510   1.915510   1.915510
# 30  low=150, high=154   1.410757   1.426161   1.426161   1.426161   1.426161
# 31  low=155, high=159   1.291360   1.301557   1.301557   1.301557   1.301557
# 32  low=160, high=164   0.914350   0.922533   0.922533   0.922533   0.922533
# 33  low=165, high=169   0.846217   0.848212   0.848212   0.848212   0.848212
# 34  low=170, high=174   0.846253   0.854810   0.854810   0.854810   0.854810
# 35  low=175, high=179   0.652067   0.655568   0.655568   0.655568   0.655568
# 36  low=180, high=184   0.602999   0.605541   0.605541   0.605541   0.605541
# 37  low=185, high=189   0.881199   0.879781   0.879781   0.879781   0.879781
# 38  low=190, high=194   0.693067   0.694911   0.694911   0.694911   0.694911
# 39  low=195, high=199   0.497874   0.496749   0.496749   0.496749   0.496749
# 40  low=200, high=204   0.522923   0.519360   0.519360   0.519360   0.519360
# 41  low=205, high=209   0.357340   0.352129   0.352129   0.352129   0.352129
# 42  low=210, high=214   0.275602   0.271642   0.271642   0.271642   0.271642
# 43  low=215, high=219  -0.053285  -0.058747  -0.058747  -0.058747  -0.058747
# 44  low=220, high=224  -0.094002  -0.104439  -0.104439  -0.104439  -0.104439
# 45  low=225, high=229  -0.191358  -0.207191  -0.207191  -0.207191  -0.207191
# 46  low=230, high=234  -0.438446  -0.451854  -0.451854  -0.451854  -0.451854
# 47  low=235, high=239  -0.650655  -0.662405  -0.662405  -0.662405  -0.662405
# 48  low=240, high=244  -0.598026  -0.611605  -0.611605  -0.611605  -0.611605
# 49  low=245, high=249  -1.053610  -1.064755  -1.064755  -1.064755  -1.064755
# 50  low=250, high=254  -1.001737  -1.009482  -1.009482  -1.009482  -1.009482

# %%
for i, band in enumerate(data):
    plt.plot(range(0, 5), band[1:], color=colors[i])
    
plt.show()

for i, band in enumerate(data_shifted):
    plt.plot(range(0, 5), band, color=colors[i])
    
plt.show()

# %% [markdown]
# ## Per bandpass PSNRs against dirty image and lowres constraint

# %%
dataset = "SGRA"

lmult = 2
cut = 20
hw = 5

path = "../results/cut_results/" + dataset + "/" + str(cut) + "/" + str(hw) + "hw/bphigh/lambda_m" + str(lmult)

data_low, data_high = split.banded_psnrs_lowresdirty(path, bands, cut, hw, nmaj_iter)

data_low_shifted = []
data_high_shifted = []
    
for x in data_low:
    firstval = x[1]
    shifted = [val - firstval for val in x[1:]]
    data_low_shifted.append(shifted)
    
for x in data_high:
    firstval = x[1]
    shifted = [val - firstval for val in x[1:]]
    data_high_shifted.append(shifted)

# %%
pd.DataFrame(data_low)
# Out:
#                  0          1          2          3          4          5
# 0    low=0, high=4  33.290750  34.037227  34.037227  34.037227  34.037227
# 1    low=5, high=9  26.007652  26.177039  26.177039  26.177039  26.177039
# 2  low=10, high=14  21.954443  22.188893  22.188893  22.188893  22.188893
# 3  low=15, high=19  10.805929  11.021384  11.021384  11.021384  11.021384
# 4  low=20, high=24   7.070142   7.216176   7.216176   7.216176   7.216176

# %%
for i, band in enumerate(data_low):
    plt.plot(range(0, 5), band[1:], color=colors[i])
    
plt.show()

for i, band in enumerate(data_low_shifted):
    plt.plot(range(0, 5), band, color=colors[i])
    
plt.show()

# %%
pd.DataFrame(data_high)
# Out:
#                     0         1         2         3         4         5
# 0     low=15, high=19  9.046220  9.140396  9.140396  9.140396  9.140396
# 1     low=20, high=24  7.074773  7.183451  7.183451  7.183451  7.183451
# 2     low=25, high=29  6.041344  6.148853  6.148853  6.148853  6.148853
# 3     low=30, high=34  5.382273  5.453920  5.453920  5.453920  5.453920
# 4     low=35, high=39  4.682621  4.726844  4.726844  4.726844  4.726844
# 5     low=40, high=44  4.498076  4.538366  4.538366  4.538366  4.538366
# 6     low=45, high=49  4.091244  4.132849  4.132849  4.132849  4.132849
# 7     low=50, high=54  3.248687  3.274039  3.274039  3.274039  3.274039
# 8     low=55, high=59  3.046948  3.073414  3.073414  3.073414  3.073414
# 9     low=60, high=64  2.779889  2.793227  2.793227  2.793227  2.793227
# 10    low=65, high=69  2.814251  2.825489  2.825489  2.825489  2.825489
# 11    low=70, high=74  2.062843  2.069102  2.069102  2.069102  2.069102
# 12    low=75, high=79  2.016267  2.021525  2.021525  2.021525  2.021525
# 13    low=80, high=84  1.713256  1.715865  1.715865  1.715865  1.715865
# 14    low=85, high=89  1.558365  1.560238  1.560238  1.560238  1.560238
# 15    low=90, high=94  1.369944  1.371390  1.371390  1.371390  1.371390
# 16    low=95, high=99  1.095456  1.097516  1.097516  1.097516  1.097516
# 17  low=100, high=104  0.928609  0.929838  0.929838  0.929838  0.929838
# 18  low=105, high=109  0.945064  0.945515  0.945515  0.945515  0.945515
# 19  low=110, high=114  0.850694  0.850739  0.850739  0.850739  0.850739
# 20  low=115, high=119  0.662507  0.662231  0.662231  0.662231  0.662231
# 21  low=120, high=124  0.716451  0.717106  0.717106  0.717106  0.717106
# 22  low=125, high=129  0.627957  0.628864  0.628864  0.628864  0.628864
# 23  low=130, high=134  0.574105  0.574870  0.574870  0.574870  0.574870
# 24  low=135, high=139  0.422270  0.422478  0.422478  0.422478  0.422478
# 25  low=140, high=144  0.392898  0.393550  0.393550  0.393550  0.393550
# 26  low=145, high=149  0.294674  0.294711  0.294711  0.294711  0.294711
# 27  low=150, high=154  0.288718  0.289041  0.289041  0.289041  0.289041
# 28  low=155, high=159  0.197233  0.197615  0.197615  0.197615  0.197615
# 29  low=160, high=164  0.158675  0.159168  0.159168  0.159168  0.159168
# 30  low=165, high=169  0.120131  0.120549  0.120549  0.120549  0.120549
# 31  low=170, high=174  0.075308  0.075069  0.075069  0.075069  0.075069
# 32  low=175, high=179  0.047774  0.047529  0.047529  0.047529  0.047529
# 33  low=180, high=184  0.049656  0.049301  0.049301  0.049301  0.049301
# 34  low=185, high=189  0.087759  0.087776  0.087776  0.087776  0.087776
# 35  low=190, high=194  0.041019  0.041359  0.041359  0.041359  0.041359
# 36  low=195, high=199  0.017024  0.017122  0.017122  0.017122  0.017122
# 37  low=200, high=204  0.052534  0.052698  0.052698  0.052698  0.052698
# 38  low=205, high=209  0.025912  0.025791  0.025791  0.025791  0.025791
# 39  low=210, high=214  0.022590  0.022640  0.022640  0.022640  0.022640
# 40  low=215, high=219  0.032028  0.032042  0.032042  0.032042  0.032042
# 41  low=220, high=224 -0.012518 -0.012505 -0.012505 -0.012505 -0.012505
# 42  low=225, high=229  0.003314  0.003091  0.003091  0.003091  0.003091
# 43  low=230, high=234 -0.002495 -0.002374 -0.002374 -0.002374 -0.002374
# 44  low=235, high=239  0.010224  0.010486  0.010486  0.010486  0.010486
# 45  low=240, high=244  0.002575  0.002302  0.002302  0.002302  0.002302
# 46  low=245, high=249 -0.024207 -0.024282 -0.024282 -0.024282 -0.024282
# 47  low=250, high=254 -0.043322 -0.043345 -0.043345 -0.043345 -0.043345

# %%
for i, band in enumerate(data_high):
    plt.plot(range(0, 5), band[1:], color=colors[i])
    
plt.show()

for i, band in enumerate(data_high_shifted):
    plt.plot(range(0, 5), band, color=colors[i])
    
plt.show()

# %% [markdown]
# ## For noiseless datasets

# %%
dataset = "SGRA"
gt = util.fromfits("../data/" + dataset + "_full_gt.fits")
lmult = 2
cut = 20
hw = 5
weight = "uniform"

path = "../results/noiseless_cut_results/" + weight + "/" + dataset + "/" + str(cut) + "/" + str(hw) + "hw/high/lambda_m" + str(lmult)

data = split.banded_psnrs(path, gt, bands, nmaj_iter)

data_shifted = []

for x in data:
    firstval = x[1]
    data_shifted.append([val - firstval for val in x[1:]])

# %%
for i, band in enumerate(data):
    plt.plot(range(0, 5), band[1:], color=colors[i])
    
plt.show()

for i, band in enumerate(data_shifted):
    plt.plot(range(0, 5), band, color=colors[i])
    
plt.show()

# %% [markdown]
# ## For a full-resolution reconstruction using all visibilities

# %%
dataset = "SGRA"
gt = util.fromfits("../data/" + dataset + "_full_gt.fits")

path = "../results/cut_results/full_recons/" + dataset + "/"
data = split.banded_psnrs(path, gt, bands, nmaj_iter)

data_shifted = []

for x in data:
    firstval = x[1]
    data_shifted.append([val - firstval for val in x[1:]])

# %%
for i, band in enumerate(data):
    plt.plot(range(0, 5), band[1:], color=colors[i])
    
plt.show()

for i, band in enumerate(data_shifted):
    plt.plot(range(0, 5), band, color=colors[i])
    
plt.show()

# %% [markdown]
# ## For different weightings of low and high

# %%
dataset = "SGRA"
gt = util.fromfits("../data/" + dataset + "_full_gt.fits")
lmult = 2
cut = 55
hw = 5
recon_noise_factor = 1000

path = "../results/cut_results/" + dataset + "/" + str(recon_noise_factor) + "/" + str(cut) + "/" + str(hw)\
    + "hw/bphigh/lambda_m" + str(lmult)

data = split.banded_psnrs(path, gt, bands, nmaj_iter)

data_shifted = []

for x in data:
    firstval = x[1]
    data_shifted.append([val - firstval for val in x[1:]])

# %%
for i, band in enumerate(data):
    plt.plot(range(0, 5), band[1:], color=colors[i])
    
plt.show()

for i, band in enumerate(data_shifted):
    plt.plot(range(0, 5), band, color=colors[i])
    
plt.show()
