# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy
import helpers
import os
import logging, sys
import math
matplotlib.rcParams['figure.figsize'] = [6, 5]

breakdowns = [
    "read",
    "grid",
    "degrid",
    "deconvolve",
    "other"
]

breakdowns_parallel = [
    "read",
    "grid",
    "degrid",
    "deconvolve",
    "wait",
    "other"
]

num_mc = 5

def total_timings(timings, breakdowns):
    total = []
    
    for i, breakdown in enumerate(breakdowns):
        curr_timing = 0

        for timing in timings:
            curr_timing += timing[i]

        total.append(curr_timing)
        
    return total

average_parallel_deconv = 0
average_serial_deconv = 0
average_msclean_deconv = 0

average_parallel_deconv_1500 = 0
average_serial_deconv_1500 = 0
average_msclean_deconv_1500 = 0

average_parallel_deconv_1728 = 0
average_serial_deconv_1728 = 0
average_msclean_deconv_1728 = 0

# %% [markdown]
# #### P.S all angular resolutions and EM frequencies for simulated datasets are not in line with the actual sources

# %% [markdown]
# ## Results for Sgr A Simulated dataset
# #### Telescope Configuration: MEERKAT
# #### Frequency Bands: 1Ghz
# #### RA and DEC: (56, -45)
# #### Observation Time (HA): (-2, 2)
# #### Samples: Every 120s
# #### $\text{V}_\mathcal{L}$ size: 132648
# #### $\text{V}_\mathcal{H}$ size: 121140
# #### $\text{V}$ size: 249600
# #### $\ell$: 30
# #### $\delta$: 1
# #### Angular Resolution: 0.00001849451rad
# #### Pixel Resolution: 512x512

# %%
sgra_res_path = "../results/ri_parallelization_results/SGRA/"

vl_parallel_breakdown_data = helpers.read_csv(sgra_res_path + "SGRA_parallel/mc_timings_breakdown_0", separate_rows=True)
vh_parallel_breakdown_data = helpers.read_csv(sgra_res_path + "SGRA_parallel/mc_timings_breakdown_1", separate_rows=True)
serial_breakdown_data = helpers.read_csv(sgra_res_path + "SGRA_serial/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = helpers.read_csv(sgra_res_path + "SGRA_msclean/mc_timings_breakdown", separate_rows=True)
vl_mscp_breakdown_data = helpers.read_csv(sgra_res_path + "SGRA_msclean_p/mc_timings_breakdown_0", separate_rows=True)
vh_mscp_breakdown_data = helpers.read_csv(sgra_res_path + "SGRA_msclean_p/mc_timings_breakdown_1", separate_rows=True)

dirty = helpers.readFits(sgra_res_path + "SGRA_serial/residual_0.fits")
helpers.plotNImages([dirty], [""], cmap="turbo", output_file="../figures/pSGRAdirty.pdf", hide_ticks=True)

compute_jacknifed_residual = False
compute_residuals = False
computed_weighted = False

# %% [markdown]
# ### Time vs Reconstruction Quality

# %%
serial_times_sep = helpers.read_csv(sgra_res_path + "SGRA_serial/mc_timings")
serial_times = []
serial_psnrs = []

msc_times_sep = helpers.read_csv(sgra_res_path + "SGRA_msclean/mc_timings")
msc_times = []
msc_psnrs = []

parallel_times_sep = helpers.read_csv(sgra_res_path + "SGRA_parallel/mc_timings")
parallel_times = []
vl_psnrs = []
vh_psnrs = []
combined_psnrs = []
combined_weighted_psnrs = []

parallel_msc_times_sep = helpers.read_csv(sgra_res_path + "SGRA_msclean_p/mc_timings")
vlmsc_psnrs = []
vhmsc_psnrs = []
combinedmsc_psnrs = []
combinedmsc_weighted_psnrs = []
parallel_msc_times = []


gt = helpers.readFits("../data/SGRA_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_psnrs.append(0)
for i in range(0, num_mc):
    curr_deconv_img = helpers.readFits(sgra_res_path + "SGRA_serial/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])

    serial_psnrs.append(helpers.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
#For msclean
curr_deconv = None
time_acc = float(msc_times_sep[0])
msc_psnrs.append(0)
msc_times.append(time_acc)
for i in range(0, num_mc):
    curr_deconv_img = helpers.readFits(sgra_res_path + "SGRA_msclean/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(msc_times_sep[i+1])

    msc_psnrs.append(helpers.compute_snr(curr_deconv, gt))
    msc_times.append(time_acc)

if compute_residuals:
    weight_grid, model = helpers.compute_weights_griddata_by_channel("../data6/SGRA_serial.ms", \
                                512, 0.00001849451, 0, 0, [0])
    
if compute_jacknifed_residual:
    if weight_grid is None:
        weight_grid, model = helpers.compute_weights_griddata_by_channel("../data6/SGRA_serial.ms", \
                                512, 0.00001849451, 0, 0, [0])
        
    jk_resid = helpers.compute_jackknifed_residual_bychannel(model, "../data6/SGRA_serial.ms",\
                                             512, 0.00001849451, "uniform", 0, weight_grid, 0, 0, [0])
    helpers.write_nparr_to_fits(jk_resid.pixels.data, sgra_res_path + "SGRA_parallel/jacknifed_resid.fits")

#parallel
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
vl_psnrs.append(0)
vh_psnrs.append(0)
combined_psnrs.append(0)
combined_weighted_psnrs.append(0)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(sgra_res_path + "SGRA_parallel/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(sgra_res_path + "SGRA_parallel/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(parallel_times_sep[i+1])
    
    if computed_weighted:
        #weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        #weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))
        weight_vl = 1 / helpers.compute_windowed_var(curr_deconv_vl, 5)
        weight_vh = 1 / helpers.compute_windowed_var(curr_deconv_vh, 5)

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        helpers.write_nparr_to_fits(curr_deconv_weighted, sgra_res_path + "SGRA_parallel/deconv_weighted_combined_" + str(i) + ".fits")
        
    curr_deconv_weighted = helpers.readFits(sgra_res_path + "SGRA_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(sgra_res_path + "SGRA_parallel/deconv_combined_" + str(i) + ".fits")
    
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../data6/SGRA_serial.ms",\
                                                 512, 0.00001849451, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../data6/SGRA_serial.ms",\
                                                 512, 0.00001849451, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../data6/SGRA_serial.ms",\
                                                 512, 0.00001849451, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, sgra_res_path + "SGRA_parallel/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, sgra_res_path + "SGRA_parallel/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, sgra_res_path + "SGRA_parallel/combined_fullresid_" + str(i) + ".fits")
        
    vl_psnrs.append(helpers.compute_snr(curr_deconv_vl, gt))
    vh_psnrs.append(helpers.compute_snr(curr_deconv_vh, gt))
    combined_psnrs.append(helpers.compute_snr(curr_deconv_combined, gt))
    combined_weighted_psnrs.append(helpers.compute_snr(curr_deconv_weighted, gt))
    parallel_times.append(time_acc)

#parallel msclean
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = float(parallel_times_sep[0])

vlmsc_psnrs.append(0)
vhmsc_psnrs.append(0)
combinedmsc_psnrs.append(0)
combinedmsc_weighted_psnrs.append(0)
parallel_msc_times.append(time_acc)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(sgra_res_path + "SGRA_msclean_p/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(sgra_res_path + "SGRA_msclean_p/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        float(parallel_msc_times_sep[i+1])
    time_acc += float(parallel_msc_times_sep[i+1]) - float(parallel_times_sep[0]) if i == 0 else float(parallel_msc_times_sep[i+1])
    
    if computed_weighted:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        print(str(weight_vl) + " " + str(weight_vh))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        helpers.write_nparr_to_fits(curr_deconv_weighted, sgra_res_path + "SGRA_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
        
    curr_deconv_weighted = helpers.readFits(sgra_res_path + "SGRA_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(sgra_res_path + "SGRA_msclean_p/deconv_combined_" + str(i) + ".fits")
      
    vlmsc_psnrs.append(helpers.compute_snr(curr_deconv_vl, gt))
    vhmsc_psnrs.append(helpers.compute_snr(curr_deconv_vh, gt))
    combinedmsc_psnrs.append(helpers.compute_snr(curr_deconv_combined, gt))
    combinedmsc_weighted_psnrs.append(helpers.compute_snr(curr_deconv_weighted, gt))
    parallel_msc_times.append(time_acc)
    
plt.plot(serial_times, serial_psnrs, c='crimson', label="$L^1$", lw=3, marker='o', markersize=10)
plt.plot(msc_times, msc_psnrs, c='darkblue', label="msc", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, vl_psnrs, c='teal', label="${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vh_psnrs, c='purple', label="${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(parallel_times, combined_psnrs, c='coral', label="p-$L^1$", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combined_weighted_psnrs, c='darkorange', label="combined weighted parallel recon", lw=2, marker='o')

#plt.plot(parallel_times, vlmsc_psnrs, c='powderblue', label="msclean ${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vhmsc_psnrs, c='plum', label="msclean ${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(parallel_msc_times, combinedmsc_psnrs, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combinedmsc_weighted_psnrs, c='moccasin', label="msclean combined weighted parallel recon", lw=2, marker='o')

plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("S/N (dB)", fontsize=16)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("../interleaved_parallelization_prototype/figures/sgra_timeacc.pdf", pad_inches=0.0, bbox_inches='tight')

sgra_l1_t = serial_times
sgra_l1p_t = parallel_times
sgra_msc_t = msc_times
sgra_mscp_t = parallel_msc_times
sgra_l1_a = serial_psnrs
sgra_l1p_a = combined_psnrs
sgra_msc_a = msc_psnrs
sgra_mscp_a = combinedmsc_psnrs

# %% [markdown]
# ### Serial breakdown

# %%
for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

average_deconv = 0

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_serial_deconv += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### multi-scale clean breakdown

# %%
for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_msclean_deconv += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_parallel_breakdown_data):
    vl_parallel_breakdown_data[i] = list(map(float, lst))

vl_weights_timings = vl_parallel_breakdown_data[1]
vl_psf_timings = vl_parallel_breakdown_data[2]
vl_wait_timings = vl_parallel_breakdown_data[3]
vl_mc_timings = vl_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_weights_timings[0], 0, 0, 0, 0, sum(vl_weights_timings[1:])])
timings.append([vl_psf_timings[0], vl_psf_timings[3], 0, 0, 0, sum(vl_psf_timings[1:2]) + vl_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_parallel_breakdown_data):
    vh_parallel_breakdown_data[i] = list(map(float, lst))

vh_weights_timings = vh_parallel_breakdown_data[1]
vh_psf_timings = vh_parallel_breakdown_data[2]
vh_wait_timings = vh_parallel_breakdown_data[3]
vh_mc_timings = vh_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_weights_timings[0], 0, 0, 0, 0, sum(vh_weights_timings[1:])])
timings.append([vh_psf_timings[0], vh_psf_timings[3], 0, 0, 0, sum(vh_psf_timings[1:2]) + vh_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_mscp_breakdown_data):
    vl_mscp_breakdown_data[i] = list(map(float, lst))

vl_mscp_weights_timings = vl_mscp_breakdown_data[1]
vl_mscp_psf_timings = vl_mscp_breakdown_data[2]
vl_mscp_wait_timings = vl_mscp_breakdown_data[3]
vl_mscp_mc_timings = vl_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_mscp_weights_timings[0], 0, 0, 0, 0, sum(vl_mscp_weights_timings[1:])])
timings.append([vl_mscp_psf_timings[0], vl_mscp_psf_timings[3], 0, 0, 0, sum(vl_mscp_psf_timings[1:2]) + vl_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_mscp_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_mscp_breakdown_data):
    vh_mscp_breakdown_data[i] = list(map(float, lst))

vh_mscp_weights_timings = vh_mscp_breakdown_data[1]
vh_mscp_psf_timings = vh_mscp_breakdown_data[2]
vh_mscp_wait_timings = vh_mscp_breakdown_data[3]
vh_mscp_mc_timings = vh_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_mscp_weights_timings[0], 0, 0, 0, 0, sum(vh_mscp_weights_timings[1:])])
timings.append([vh_mscp_psf_timings[0], vh_mscp_psf_timings[3], 0, 0, 0, sum(vh_mscp_psf_timings[1:2]) + vh_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgra_timings_mscp_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Results for Sgr B Simulated dataset
# #### Telescope Configuration: SKA-MID (full 197)
# #### Frequency Bands: 1Ghz
# #### RA and DEC: (56, -50)
# #### Observation Time (HA): (-2, 2)
# #### Samples: Every 30s
# #### $\text{V}_\mathcal{L}$ size: 6989812
# #### $\text{V}_\mathcal{H}$ size: 2532615
# #### $\text{V}$ size: 9361440
# #### $\ell$: 20
# #### $\delta$: 1
# #### Angular Resolution: 0.0000008755170341876385rad
# #### Pixel Resolution: 512x512

# %%
sgrb_res_path = "../results/ri_parallelization_results/SGRB/"

vl_parallel_breakdown_data = helpers.read_csv(sgrb_res_path + "SGRB_parallel/mc_timings_breakdown_0", separate_rows=True)
vh_parallel_breakdown_data = helpers.read_csv(sgrb_res_path + "SGRB_parallel/mc_timings_breakdown_1", separate_rows=True)
serial_breakdown_data = helpers.read_csv(sgrb_res_path + "SGRB_serial/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = helpers.read_csv(sgrb_res_path + "SGRB_msclean/mc_timings_breakdown", separate_rows=True)
vl_mscp_breakdown_data = helpers.read_csv(sgrb_res_path + "SGRB_msclean_p/mc_timings_breakdown_0", separate_rows=True)
vh_mscp_breakdown_data = helpers.read_csv(sgrb_res_path + "SGRB_msclean_p/mc_timings_breakdown_1", separate_rows=True)

dirty = helpers.readFits(sgrb_res_path + "SGRB_serial/residual_0.fits")
helpers.plotNImages([dirty], [""], cmap="turbo", output_file="../figures/pSGRBdirty.pdf", hide_ticks=True)

compute_residuals = False
compute_jacknifed_residual = False
computed_weighted = False

# %% [markdown]
# ### Time vs Reconstruction Quality

# %%
serial_times_sep = helpers.read_csv(sgrb_res_path + "SGRB_serial/mc_timings")
serial_times = []
serial_psnrs = []

msc_times_sep = helpers.read_csv(sgrb_res_path + "SGRB_msclean/mc_timings")
msc_times = []
msc_psnrs = []

parallel_times_sep = helpers.read_csv(sgrb_res_path + "SGRB_parallel/mc_timings")
parallel_times = []
vl_psnrs = []
vh_psnrs = []
combined_psnrs = []
combined_weighted_psnrs = []

mscp_times_sep = helpers.read_csv(sgrb_res_path + "SGRB_msclean_p/mc_timings")
mscp_times = []
vlmsc_psnrs = []
vhmsc_psnrs = []
combinedmsc_psnrs = []
combinedmsc_weighted_psnrs = []

gt = helpers.readFits("../data/SGRB_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_psnrs.append(0)
for i in range(0, num_mc):
    curr_deconv_img = helpers.readFits(sgrb_res_path + "SGRB_serial/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])

    serial_psnrs.append(helpers.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
#For msclean
curr_deconv = None
time_acc = float(msc_times_sep[0])
msc_times.append(time_acc)
msc_psnrs.append(0)
for i in range(0, num_mc):
    curr_deconv_img = helpers.readFits(sgrb_res_path + "SGRB_msclean/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(msc_times_sep[i+1])

    msc_psnrs.append(helpers.compute_snr(curr_deconv, gt))
    msc_times.append(time_acc)

if compute_residuals:
    weight_grid, model = helpers.compute_weights_griddata_by_channel("../data6/SGRB_serial.ms", \
                                512, 0.0000008755170341876385, 0, 0, [0])
    
if compute_jacknifed_residual:
    if weight_grid is None:
        weight_grid, model = helpers.compute_weights_griddata_by_channel("../data6/SGRB_serial.ms", \
                                512, 0.0000008755170341876385, 0, 0, [0])
    jk_resid = helpers.compute_jackknifed_residual_bychannel(model, "../data6/SGRB_serial.ms",\
                                             512, 0.0000008755170341876385, "uniform", 0, weight_grid, 0, 0, [0])
    helpers.write_nparr_to_fits(jk_resid.pixels.data, sgrb_res_path + "SGRB_parallel/jacknifed_resid.fits")

#parallel 
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = float(parallel_times_sep[0])

parallel_times.append(time_acc)
vl_psnrs.append(0)
vh_psnrs.append(0)
combined_psnrs.append(0)
combined_weighted_psnrs.append(0)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(sgrb_res_path + "SGRB_parallel/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(sgrb_res_path + "SGRB_parallel/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(parallel_times_sep[i+1])
    
    if computed_weighted:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        helpers.write_nparr_to_fits(curr_deconv_weighted, sgrb_res_path + "SGRB_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(sgrb_res_path + "SGRB_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(sgrb_res_path + "SGRB_parallel/deconv_combined_" + str(i) + ".fits")
    
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../data6/SGRB_serial.ms",\
                                                 512, 0.0000008755170341876385, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../data6/SGRB_serial.ms",\
                                                 512, 0.0000008755170341876385, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../data6/SGRB_serial.ms",\
                                                 512, 0.0000008755170341876385, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, sgrb_res_path + "SGRB_parallel/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, sgrb_res_path + "SGRB_parallel/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, sgrb_res_path + "SGRB_parallel/combined_fullresid_" + str(i) + ".fits")
    
    vl_psnrs.append(helpers.compute_snr(curr_deconv_vl, gt))
    vh_psnrs.append(helpers.compute_snr(curr_deconv_vh, gt))
    combined_psnrs.append(helpers.compute_snr(curr_deconv_combined, gt))
    combined_weighted_psnrs.append(helpers.compute_snr(curr_deconv_weighted, gt))
    parallel_times.append(time_acc)
    
    
#parallel msclean
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = float(parallel_times_sep[0])
mscp_times.append(time_acc)
vlmsc_psnrs.append(0)
vhmsc_psnrs.append(0)
combinedmsc_psnrs.append(0)
combinedmsc_weighted_psnrs.append(0)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(sgrb_res_path + "SGRB_msclean_p/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(sgrb_res_path + "SGRB_msclean_p/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(mscp_times_sep[i+1]) - float(parallel_times_sep[0]) if i == 0 else float(mscp_times_sep[i+1])
    
    if computed_weighted:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        helpers.write_nparr_to_fits(curr_deconv_weighted, sgrb_res_path + "SGRB_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(sgrb_res_path + "SGRB_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(sgrb_res_path + "SGRB_msclean_p/deconv_combined_" + str(i) + ".fits")
      
    vlmsc_psnrs.append(helpers.compute_snr(curr_deconv_vl, gt))
    vhmsc_psnrs.append(helpers.compute_snr(curr_deconv_vh, gt))
    combinedmsc_psnrs.append(helpers.compute_snr(curr_deconv_combined, gt))
    combinedmsc_weighted_psnrs.append(helpers.compute_snr(curr_deconv_weighted, gt))
    mscp_times.append(time_acc)
    
    
plt.plot(serial_times, serial_psnrs, c='crimson', label="$L^1$", lw=3, marker='o', markersize=10)
plt.plot(msc_times, msc_psnrs, c='darkblue', label="msc", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, vl_psnrs, c='teal', label="${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vh_psnrs, c='purple', label="${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(parallel_times, combined_psnrs, c='coral', label="p-$L^1$ recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combined_weighted_psnrs, c='darkorange', label="combined weighted parallel recon", lw=2, marker='o')

#plt.plot(parallel_times, vlmsc_psnrs, c='powderblue', label="msclean ${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vhmsc_psnrs, c='plum', label="msclean ${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(mscp_times, combinedmsc_psnrs, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combinedmsc_weighted_psnrs, c='moccasin', label="msclean combined weighted parallel recon", lw=2, marker='o')

plt.xlabel("Time (s)", fontsize=20)
plt.ylabel("S/N (dB)", fontsize=20)
#plt.yscale('log')
plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrb_timeacc.pdf", pad_inches=0.0, bbox_inches='tight')

sgrb_l1_t = serial_times
sgrb_l1p_t = parallel_times
sgrb_msc_t = msc_times
sgrb_mscp_t = mscp_times
sgrb_l1_a = serial_psnrs
sgrb_l1p_a = combined_psnrs
sgrb_msc_a = msc_psnrs
sgrb_mscp_a = combinedmsc_psnrs

# %% [markdown]
# ### Serial breakdown

# %%
for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_serial_deconv += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### multi-scale clean breakdown

# %%
for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_msclean_deconv += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_parallel_breakdown_data):
    vl_parallel_breakdown_data[i] = list(map(float, lst))

vl_weights_timings = vl_parallel_breakdown_data[1]
vl_psf_timings = vl_parallel_breakdown_data[2]
vl_wait_timings = vl_parallel_breakdown_data[3]
vl_mc_timings = vl_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_weights_timings[0], 0, 0, 0, 0, sum(vl_weights_timings[1:])])
timings.append([vl_psf_timings[0], vl_psf_timings[3], 0, 0, 0, sum(vl_psf_timings[1:2]) + vl_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_parallel_breakdown_data):
    vh_parallel_breakdown_data[i] = list(map(float, lst))

vh_weights_timings = vh_parallel_breakdown_data[1]
vh_psf_timings = vh_parallel_breakdown_data[2]
vh_wait_timings = vh_parallel_breakdown_data[3]
vh_mc_timings = vh_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_weights_timings[0], 0, 0, 0, 0, sum(vh_weights_timings[1:])])
timings.append([vh_psf_timings[0], vh_psf_timings[3], 0, 0, 0, sum(vh_psf_timings[1:2]) + vh_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_mscp_breakdown_data):
    vl_mscp_breakdown_data[i] = list(map(float, lst))

vl_mscp_weights_timings = vl_mscp_breakdown_data[1]
vl_mscp_psf_timings = vl_mscp_breakdown_data[2]
vl_mscp_wait_timings = vl_mscp_breakdown_data[3]
vl_mscp_mc_timings = vl_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_mscp_weights_timings[0], 0, 0, 0, 0, sum(vl_mscp_weights_timings[1:])])
timings.append([vl_mscp_psf_timings[0], vl_mscp_psf_timings[3], 0, 0, 0, sum(vl_mscp_psf_timings[1:2]) + vl_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_mscp_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_mscp_breakdown_data):
    vh_mscp_breakdown_data[i] = list(map(float, lst))

vh_mscp_weights_timings = vh_mscp_breakdown_data[1]
vh_mscp_psf_timings = vh_mscp_breakdown_data[2]
vh_mscp_wait_timings = vh_mscp_breakdown_data[3]
vh_mscp_mc_timings = vh_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_mscp_weights_timings[0], 0, 0, 0, 0, sum(vh_mscp_weights_timings[1:])])
timings.append([vh_mscp_psf_timings[0], vh_mscp_psf_timings[3], 0, 0, 0, sum(vh_mscp_psf_timings[1:2]) + vh_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrb_timings_mscp_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Results for Sgr C Simulated dataset
# #### Telescope Configuration: SKA-LOW (full 512)
# #### Frequency Bands: 1Ghz
# #### RA and DEC: (56, -35)
# #### Observation Time (HA): (-2, 2)
# #### Samples: Every 120s
# #### $\text{V}_\mathcal{L}$ size: 9053277
# #### $\text{V}_\mathcal{H}$ size: 6811266
# #### $\text{V}$ size: 15759360
# #### $\ell$: 25
# #### $\delta$: 1
# #### Angular Resolution: 0.0000020815303069902844rad
# #### Pixel Resolution: 512x512

# %%
sgrc_res_path = "../results/ri_parallelization_results/SGRC/"

vl_parallel_breakdown_data = helpers.read_csv(sgrc_res_path + "SGRC_parallel/mc_timings_breakdown_0", separate_rows=True)
vh_parallel_breakdown_data = helpers.read_csv(sgrc_res_path + "SGRC_parallel/mc_timings_breakdown_1", separate_rows=True)
serial_breakdown_data = helpers.read_csv(sgrc_res_path + "SGRC_serial/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = helpers.read_csv(sgrc_res_path + "SGRC_msclean/mc_timings_breakdown", separate_rows=True)
vl_mscp_breakdown_data = helpers.read_csv(sgrc_res_path + "SGRC_msclean_p/mc_timings_breakdown_0", separate_rows=True)
vh_mscp_breakdown_data = helpers.read_csv(sgrc_res_path + "SGRC_msclean_p/mc_timings_breakdown_1", separate_rows=True)

dirty = helpers.readFits(sgrc_res_path + "SGRC_serial/residual_0.fits")
helpers.plotNImages([dirty], [""], cmap="turbo", output_file="../figures/pSGRCdirty.pdf", hide_ticks=True)

compute_residuals = False
compute_jacknifed_residual = False
computed_weighted = False

# %% [markdown]
# ### Time vs Reconstruction Quality

# %%
serial_times_sep = helpers.read_csv(sgrc_res_path + "SGRC_serial/mc_timings")
serial_times = []
serial_psnrs = []

msc_times_sep = helpers.read_csv(sgrc_res_path + "SGRC_msclean/mc_timings")
msc_times = []
msc_psnrs = []

parallel_times_sep = helpers.read_csv(sgrc_res_path + "SGRC_parallel/mc_timings")
parallel_times = []
vl_psnrs = []
vh_psnrs = []
combined_psnrs = []
combined_weighted_psnrs = []

mscp_times_sep = helpers.read_csv(sgrc_res_path + "SGRC_msclean_p/mc_timings")
mscp_times = []
vlmsc_psnrs = []
vhmsc_psnrs = []
combinedmsc_psnrs = []
combinedmsc_weighted_psnrs = []

gt = helpers.readFits("../data/SGRC_full_gt.fits")

#For serial
curr_deconv = None
time_acc = float(serial_times_sep[0])
serial_times.append(time_acc)
serial_psnrs.append(0)
for i in range(0, num_mc):
    curr_deconv_img = helpers.readFits(sgrc_res_path + "SGRC_serial/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i+1])

    serial_psnrs.append(helpers.compute_snr(curr_deconv, gt))
    serial_times.append(time_acc)
    
#For msclean
curr_deconv = None
time_acc = float(msc_times_sep[0])
msc_times.append(time_acc)
msc_psnrs.append(0)
for i in range(0, num_mc):
    curr_deconv_img = helpers.readFits(sgrc_res_path + "SGRC_msclean/deconvolved_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(msc_times_sep[i+1])

    msc_psnrs.append(helpers.compute_snr(curr_deconv, gt))
    msc_times.append(time_acc)

if compute_residuals:
    weight_grid, model = helpers.compute_weights_griddata_by_channel("../data6/SGRC_serial.ms", \
                                512, 0.0000020815303069902844, 0, 0, [0])
    
if compute_jacknifed_residual:
    if weight_grid is None:
        weight_grid, model = helpers.compute_weights_griddata_by_channel("../data6/SGRC_serial.ms", \
                                512, 0.0000020815303069902844, 0, 0, [0])
    jk_resid = helpers.compute_jackknifed_residual_bychannel(model, "../data6/SGRC_serial.ms",\
                                             512, 0.0000020815303069902844, "uniform", 0, weight_grid, 0, 0, [0])
    helpers.write_nparr_to_fits(jk_resid.pixels.data, sgrc_res_path + "SGRC_parallel/jacknifed_resid.fits")
    
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = float(parallel_times_sep[0])
parallel_times.append(time_acc)
vl_psnrs.append(0)
vh_psnrs.append(0)
combined_psnrs.append(0)
combined_weighted_psnrs.append(0)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(sgrc_res_path + "SGRC_parallel/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(sgrc_res_path + "SGRC_parallel/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(parallel_times_sep[i+1])
    
    if computed_weighted:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total
    
        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        helpers.write_nparr_to_fits(curr_deconv_weighted, sgrc_res_path + "SGRC_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(sgrc_res_path + "SGRC_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(sgrc_res_path + "SGRC_parallel/deconv_combined_" + str(i) + ".fits")
        
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../.data6/SGRC_serial.ms",\
                                                 512, 0.0000020815303069902844, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../data6/SGRC_serial.ms",\
                                                 512, 0.0000020815303069902844, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../data6/SGRC_serial.ms",\
                                                 512, 0.0000020815303069902844, "uniform", 0, weight_grid, \
                                                 0, 0, [0])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, sgrc_res_path + "SGRC_parallel/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, sgrc_res_path + "SGRC_parallel/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, sgrc_res_path + "SGRC_parallel/combined_fullresid_" + str(i) + ".fits")
        
    vl_psnrs.append(helpers.compute_snr(curr_deconv_vl, gt))
    vh_psnrs.append(helpers.compute_snr(curr_deconv_vh, gt))
    combined_psnrs.append(helpers.compute_snr(curr_deconv_combined, gt))
    combined_weighted_psnrs.append(helpers.compute_snr(curr_deconv_weighted, gt))
    parallel_times.append(time_acc)
    
    
#parallel msclean
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = float(parallel_times_sep[0])
mscp_times.append(time_acc)
vlmsc_psnrs.append(0)
vhmsc_psnrs.append(0)
combinedmsc_psnrs.append(0)
combinedmsc_weighted_psnrs.append(0)
    
for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(sgrc_res_path + "SGRC_msclean_p/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(sgrc_res_path + "SGRC_msclean_p/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(mscp_times_sep[i+1]) - float(parallel_times_sep[0]) if i == 0 else float(mscp_times_sep[i+1])
        
    if computed_weighted:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total
    
        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        helpers.write_nparr_to_fits(curr_deconv_weighted, sgrc_res_path + "SGRC_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(sgrc_res_path + "SGRC_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(sgrc_res_path + "SGRC_msclean_p/deconv_combined_" + str(i) + ".fits")
      
    vlmsc_psnrs.append(helpers.compute_snr(curr_deconv_vl, gt))
    vhmsc_psnrs.append(helpers.compute_snr(curr_deconv_vh, gt))
    combinedmsc_psnrs.append(helpers.compute_snr(curr_deconv_combined, gt))
    combinedmsc_weighted_psnrs.append(helpers.compute_snr(curr_deconv_weighted, gt))
    mscp_times.append(time_acc)
    
    
plt.plot(serial_times, serial_psnrs, c='crimson', label="serial $\ell^1$ recon", lw=3, marker='o', markersize=10)
plt.plot(msc_times, msc_psnrs, c='darkblue', label="serial ms-clean recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, vl_psnrs, c='teal', label="${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vh_psnrs, c='purple', label="${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(parallel_times, combined_psnrs, c='coral', label="parallel $\ell^1$ recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combined_weighted_psnrs, c='darkorange', label="combined weighted parallel recon", lw=2, marker='o')

#plt.plot(parallel_times, vlmsc_psnrs, c='powderblue', label="msclean ${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vhmsc_psnrs, c='plum', label="msclean ${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(mscp_times, combinedmsc_psnrs, c='dodgerblue', label="parallel ms-clean recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combinedmsc_weighted_psnrs, c='moccasin', label="msclean combined weighted parallel recon", lw=2, marker='o')

plt.xlabel("Time (s)", fontsize=20)
plt.ylabel("S/N (dB)", fontsize=20)
#plt.yscale('log')
#plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrc_timeacc.pdf", pad_inches=0.0, bbox_inches='tight')

sgrc_l1_t = serial_times
sgrc_l1p_t = parallel_times
sgrc_msc_t = msc_times
sgrc_mscp_t = mscp_times
sgrc_l1_a = serial_psnrs
sgrc_l1p_a = combined_psnrs
sgrc_msc_a = msc_psnrs
sgrc_mscp_a = combinedmsc_psnrs

# %% [markdown]
# ### Serial breakdown

# %%
for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_serial_deconv += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean breakdown

# %%
for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_msclean_deconv += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_parallel_breakdown_data):
    vl_parallel_breakdown_data[i] = list(map(float, lst))

vl_weights_timings = vl_parallel_breakdown_data[1]
vl_psf_timings = vl_parallel_breakdown_data[2]
vl_wait_timings = vl_parallel_breakdown_data[3]
vl_mc_timings = vl_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_weights_timings[0], 0, 0, 0, 0, sum(vl_weights_timings[1:])])
timings.append([vl_psf_timings[0], vl_psf_timings[3], 0, 0, 0, sum(vl_psf_timings[1:2]) + vl_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_parallel_breakdown_data):
    vh_parallel_breakdown_data[i] = list(map(float, lst))

vh_weights_timings = vh_parallel_breakdown_data[1]
vh_psf_timings = vh_parallel_breakdown_data[2]
vh_wait_timings = vh_parallel_breakdown_data[3]
vh_mc_timings = vh_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_weights_timings[0], 0, 0, 0, 0, sum(vh_weights_timings[1:])])
timings.append([vh_psf_timings[0], vh_psf_timings[3], 0, 0, 0, sum(vh_psf_timings[1:2]) + vh_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_mscp_breakdown_data):
    vl_mscp_breakdown_data[i] = list(map(float, lst))

vl_mscp_weights_timings = vl_mscp_breakdown_data[1]
vl_mscp_psf_timings = vl_mscp_breakdown_data[2]
vl_mscp_wait_timings = vl_mscp_breakdown_data[3]
vl_mscp_mc_timings = vl_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_mscp_weights_timings[0], 0, 0, 0, 0, sum(vl_mscp_weights_timings[1:])])
timings.append([vl_mscp_psf_timings[0], vl_mscp_psf_timings[3], 0, 0, 0, sum(vl_mscp_psf_timings[1:2]) + vl_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_mscp_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_mscp_breakdown_data):
    vh_mscp_breakdown_data[i] = list(map(float, lst))

vh_mscp_weights_timings = vh_mscp_breakdown_data[1]
vh_mscp_psf_timings = vh_mscp_breakdown_data[2]
vh_mscp_wait_timings = vh_mscp_breakdown_data[3]
vh_mscp_mc_timings = vh_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_mscp_weights_timings[0], 0, 0, 0, 0, sum(vh_mscp_weights_timings[1:])])
timings.append([vh_mscp_psf_timings[0], vh_mscp_psf_timings[3], 0, 0, 0, sum(vh_mscp_psf_timings[1:2]) + vh_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
sgrc_timings_mscp_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Results for HL Tau dataset
# #### Telescope Configuration: ALMA maximum baseline(?)
# #### Frequency Bands: 4x4, 224.750GHz - 228.750GHz, 239.250 - 243.250 GHz, 0.5GHz width per channel
# #### RA and DEC: (38.42, 57.25)
# #### $\text{V}_\mathcal{L}$ size: 39864808
# #### $\text{V}_\mathcal{H}$ size: 46243732
# #### $\text{V}$ size: 85502624
# #### $\ell$: 60
# #### $\delta$: 1
# #### Angular Resolution: 0.000000024240684rad
# #### Pixel Resolution: 1500x1500

# %%
hltau_res_path = "../results/ri_parallelization_results/HLTau_B6/"

vl_parallel_breakdown_data = helpers.read_csv(hltau_res_path + "HLTau_B6_parallel/mc_timings_breakdown_0", separate_rows=True)
vh_parallel_breakdown_data = helpers.read_csv(hltau_res_path + "HLTau_B6_parallel/mc_timings_breakdown_1", separate_rows=True)
serial_breakdown_data = helpers.read_csv(hltau_res_path + "HLTau_B6_serial/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = helpers.read_csv(hltau_res_path + "HLTau_B6_msclean/mc_timings_breakdown", separate_rows=True)
vl_mscp_breakdown_data = helpers.read_csv(hltau_res_path + "HLTau_B6_msclean_p/mc_timings_breakdown_0", separate_rows=True)
vh_mscp_breakdown_data = helpers.read_csv(hltau_res_path + "HLTau_B6_msclean_p/mc_timings_breakdown_1", separate_rows=True)

dirty = helpers.readFits(hltau_res_path + "HLTau_B6_serial/residual_0.fits")
helpers.plotNImages([dirty], [""], cmap="turbo", output_file="../figures/pHLTAUdirty.pdf", hide_ticks=True)

compute_residuals = False
compute_jacknifed_residual = False
calculate_pvals = False
compute_weighted_combined = False

# %% [markdown]
# ### Time vs Reconstruction Quality

# %%
serial_times_sep = helpers.read_csv(hltau_res_path + "HLTau_B6_serial/mc_timings")
serial_times = []
serial_residuals = []
serial_pnorms = []

msc_times_sep = helpers.read_csv(hltau_res_path + "HLTau_B6_msclean/mc_timings")
msc_times = []
msc_residuals = []
msc_pnorms = []

parallel_times_sep = helpers.read_csv(hltau_res_path + "HLTau_B6_parallel/mc_timings")
parallel_times = []
vl_residuals = []
vh_residuals = []
combined_residuals = []
combined_weighted_residuals = []
vl_pnorms = []
vh_pnorms = []
combined_pnorms = []
combined_weighted_pnorms = []

mscp_times_sep = helpers.read_csv(hltau_res_path + "HLTau_B6_msclean_p/mc_timings")
mscp_times = []
vl_mscp_residuals = []
vh_mscp_residuals = []
combined_mscp_residuals = []
combined_mscp_weighted_residuals = []
vl_mscp_pnorms = []
vh_mscp_pnorms = []
combined_mscp_pnorms = []
combined_mscp_weighted_pnorms = []

weight_grid = model = None

if compute_residuals:
    weight_grid, model = helpers.compute_weights_griddata_by_channel("../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms", 
                                1500, 0.000000024240684, 0, 3, [0, 1, 2, 3])
    
if compute_jacknifed_residual:
    if weight_grid is None:
        weight_grid, model = helpers.compute_weights_griddata_by_channel("../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms", 
                                1500, 0.000000024240684, 0, 3, [0, 1, 2, 3])
    jk_resid = helpers.compute_jackknifed_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                             1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                             0, 3, [0, 1, 2, 3])
    helpers.write_nparr_to_fits(jk_resid.pixels.data, hltau_res_path + "HLTau_B6_parallel/jacknifed_resid.fits")

jackknifed = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/jacknifed_resid.fits")
jackknifed_resid = numpy.linalg.norm(jackknifed)

#For serial
curr_deconv = None
time_acc = 0
for i in range(0, num_mc + 1):
    curr_deconv_img = helpers.readFits(hltau_res_path + "HLTau_B6_serial/deconvolved_" + str(i) + ".fits")
    curr_resid_img = helpers.readFits(hltau_res_path + "HLTau_B6_serial/residual_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i])
    
    if calculate_pvals:
        serial_pvals, serial_pnorm = helpers.t_test_image(curr_resid_img, jackknifed, 5)
        helpers.write_nparr_to_fits(serial_pvals, hltau_res_path + "HLTau_B6_serial/serial_pvals_" + str(i) + ".fits")
    
    serial_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_serial/serial_pvals_" + str(i) + ".fits")

    serial_pnorms.append(numpy.linalg.norm(serial_pvals))

    serial_residuals.append(numpy.linalg.norm(curr_resid_img))
    serial_times.append(time_acc)


#For msc
curr_deconv = None
time_acc = 0
for i in range(0, num_mc + 1):
    curr_deconv_img = helpers.readFits(hltau_res_path + "HLTau_B6_msclean/deconvolved_" + str(i) + ".fits")
    curr_resid_img = helpers.readFits(hltau_res_path + "HLTau_B6_msclean/residual_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(msc_times_sep[i])
    
    if calculate_pvals:
        msc_pvals, msc_pnorm = helpers.t_test_image(curr_resid_img, jackknifed, 5)
        helpers.write_nparr_to_fits(msc_pvals, hltau_res_path + "HLTau_B6_msclean/msc_pvals_" + str(i) + ".fits")
    
    msc_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_msclean/msc_pvals_" + str(i) + ".fits")

    msc_pnorms.append(numpy.linalg.norm(msc_pvals))
    msc_residuals.append(numpy.linalg.norm(curr_resid_img))
    msc_times.append(time_acc)

#for parallel l1
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = 0

init_resid_img = helpers.readFits(hltau_res_path + "HLTau_B6_serial/residual_0.fits")
init_resid_norm = numpy.linalg.norm(init_resid_img)

init_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_serial/serial_pvals_0.fits")
init_pnorm = numpy.linalg.norm(init_pvals)

vl_residuals.append(init_resid_norm)
vh_residuals.append(init_resid_norm)
combined_residuals.append(init_resid_norm)
vl_pnorms.append(init_pnorm)
vh_pnorms.append(init_pnorm)
combined_pnorms.append(init_pnorm)
combined_weighted_pnorms.append(init_pnorm)
time_acc += float(parallel_times_sep[0])
parallel_times.append(time_acc)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img

    helpers.write_nparr_to_fits(curr_deconv_vl, hltau_res_path + "test_vl" + str(i) + ".fits")
        
    time_acc += float(parallel_times_sep[i+1])
    
    if compute_weighted_combined:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        
        helpers.write_nparr_to_fits(curr_deconv_weighted, hltau_res_path + "HLTau_B6_parallel/combined_weighted_fullresid_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/combined_weighted_fullresid_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/deconv_combined_" + str(i) + ".fits")
        
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        model.pixels.data[0, 0, :, :] = curr_deconv_weighted
        combined_residual_weighted = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, hltau_res_path + "HLTau_B6_parallel/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, hltau_res_path + "HLTau_B6_parallel/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, hltau_res_path + "HLTau_B6_parallel/combined_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual_weighted.pixels.data, hltau_res_path + "HLTau_B6_parallel/combined_fullresid_weighted_" + str(i) + ".fits")

    vl_residual = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/vl_fullresid_" + str(i) + ".fits")
    vh_residual = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/vh_fullresid_" + str(i) + ".fits")
    combined_residual = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/combined_fullresid_" + str(i) + ".fits")
    combined_residual_weighted = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/combined_fullresid_weighted_" + str(i) + ".fits")
    
    if calculate_pvals:
        #vl_pvals, vl_pnorm = helpers.t_test_image(vl_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vl_pvals, hltau_res_path + "HLTau_B6_parallel/vl_pvals_" + str(i) + ".fits")
        #vh_pvals, vh_pnorm = helpers.t_test_image(vh_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vh_pvals, hltau_res_path + "HLTau_B6_parallel/vh_pvals_" + str(i) + ".fits")
        combined_pvals, combined_pnorm = helpers.t_test_image(combined_residual, jackknifed, 5)
        helpers.write_nparr_to_fits(combined_pvals, hltau_res_path + "HLTau_B6_parallel/combined_pvals_" + str(i) + ".fits")
        #combined_weighted_pvals, combined_weighted_pnorm = helpers.t_test_image(combined_residual_weighted, jackknifed, 5)
        #helpers.write_nparr_to_fits(combined_weighted_pvals, hltau_res_path + "HLTau_B6_parallel/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/vl_pvals_" + str(i) + ".fits")
    vh_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/vh_pvals_" + str(i) + ".fits")
    combined_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/combined_pvals_" + str(i) + ".fits")
    combined_weighted_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_parallel/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_residuals.append(numpy.linalg.norm(vl_residual))
    vh_residuals.append(numpy.linalg.norm(vh_residual))
    combined_residuals.append(numpy.linalg.norm(combined_residual))
    combined_weighted_residuals.append(numpy.linalg.norm(combined_residual_weighted))
    
    vl_pnorms.append(numpy.linalg.norm(vl_pvals))
    vh_pnorms.append(numpy.linalg.norm(vh_pvals))
    combined_pnorms.append(numpy.linalg.norm(combined_pvals))
    combined_weighted_pnorms.append(numpy.linalg.norm(combined_weighted_pvals))
    
    parallel_times.append(time_acc)
    
    
#for parallel msclean
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = 0

vl_mscp_residuals.append(init_resid_norm)
vh_mscp_residuals.append(init_resid_norm)
combined_mscp_residuals.append(init_resid_norm)
vl_mscp_pnorms.append(init_pnorm)
vh_mscp_pnorms.append(init_pnorm)
combined_mscp_pnorms.append(init_pnorm)
combined_mscp_weighted_pnorms.append(init_pnorm)
time_acc += float(parallel_times_sep[0])
mscp_times.append(time_acc)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img

    helpers.write_nparr_to_fits(curr_deconv_vl, hltau_res_path + "test_vl" + str(i) + ".fits")
        
    time_acc += float(mscp_times_sep[i+1]) - float(parallel_times_sep[0]) if i == 0 else float(mscp_times_sep[i+1])
    
    if compute_weighted_combined:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        
        helpers.write_nparr_to_fits(curr_deconv_weighted, hltau_res_path + "HLTau_B6_msclean_p/combined_weighted_fullresid_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/combined_weighted_fullresid_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/deconv_combined_" + str(i) + ".fits")
        
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        model.pixels.data[0, 0, :, :] = curr_deconv_weighted
        combined_residual_weighted = helpers.compute_residual_bychannel(model, "../../hltau/HLTau_Band6_CalibratedData/HLTau_B6cont.calib.ms",\
                                                 1500, 0.000000024240684, "uniform", 0, weight_grid, \
                                                 0, 3, [0, 1, 2, 3])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, hltau_res_path + "HLTau_B6_msclean_p/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, hltau_res_path + "HLTau_B6_msclean_p/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, hltau_res_path + "HLTau_B6_msclean_p/combined_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual_weighted.pixels.data, hltau_res_path + "HLTau_B6_msclean_p/combined_fullresid_weighted_" + str(i) + ".fits")

    vl_residual = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/vl_fullresid_" + str(i) + ".fits")
    vh_residual = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/vh_fullresid_" + str(i) + ".fits")
    combined_residual = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/combined_fullresid_" + str(i) + ".fits")
    combined_residual_weighted = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/combined_fullresid_weighted_" + str(i) + ".fits")
    
    if calculate_pvals:
        #vl_pvals, vl_pnorm = helpers.t_test_image(vl_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vl_pvals, hltau_res_path + "HLTau_B6_msclean_p/vl_pvals_" + str(i) + ".fits")
        #vh_pvals, vh_pnorm = helpers.t_test_image(vh_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vh_pvals, hltau_res_path + "HLTau_B6_msclean_p/vh_pvals_" + str(i) + ".fits")
        combined_pvals, combined_pnorm = helpers.t_test_image(combined_residual, jackknifed, 5)
        helpers.write_nparr_to_fits(combined_pvals, hltau_res_path + "HLTau_B6_msclean_p/combined_pvals_" + str(i) + ".fits")
        #combined_weighted_pvals, combined_weighted_pnorm = helpers.t_test_image(combined_residual_weighted, jackknifed, 5)
        #helpers.write_nparr_to_fits(combined_weighted_pvals, hltau_res_path + "HLTau_B6_msclean_p/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/vl_pvals_" + str(i) + ".fits")
    vh_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/vh_pvals_" + str(i) + ".fits")
    combined_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/combined_pvals_" + str(i) + ".fits")
    combined_weighted_pvals = helpers.readFits(hltau_res_path + "HLTau_B6_msclean_p/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_mscp_residuals.append(numpy.linalg.norm(vl_residual))
    vh_mscp_residuals.append(numpy.linalg.norm(vh_residual))
    combined_mscp_residuals.append(numpy.linalg.norm(combined_residual))
    combined_mscp_weighted_residuals.append(numpy.linalg.norm(combined_residual_weighted))
    
    vl_mscp_pnorms.append(numpy.linalg.norm(vl_pvals))
    vh_mscp_pnorms.append(numpy.linalg.norm(vh_pvals))
    combined_mscp_pnorms.append(numpy.linalg.norm(combined_pvals))
    combined_mscp_weighted_pnorms.append(numpy.linalg.norm(combined_weighted_pvals))
    
    mscp_times.append(time_acc)
    
plt.plot(serial_times, serial_pnorms, c='crimson', label="serial $\ell^1$ recon", lw=3, marker='o', markersize=10)
plt.plot(msc_times, msc_pnorms, c='darkblue', label="serial ms-clean recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, vl_psnrs, c='teal', label="${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vh_psnrs, c='purple', label="${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(parallel_times, combined_pnorms, c='coral', label="parallel $\ell^1$ recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combined_weighted_psnrs, c='darkorange', label="combined weighted parallel recon", lw=2, marker='o')

#plt.plot(parallel_times, vlmsc_psnrs, c='powderblue', label="msclean ${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vhmsc_psnrs, c='plum', label="msclean ${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(mscp_times, combined_mscp_pnorms, c='dodgerblue', label="parallel ms-clean recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combinedmsc_weighted_psnrs, c='moccasin', label="msclean combined weighted parallel recon", lw=2, marker='o')

plt.xlabel("Time (s)", fontsize=20)
plt.ylabel("S/N (dB)", fontsize=20)
#plt.yscale('log')
#plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.savefig("../interleaved_parallelization_prototype/figures/hltau_timeacc.pdf", pad_inches=0.0, bbox_inches='tight')

hltau_l1_t = serial_times
hltau_l1p_t = parallel_times
hltau_msc_t = msc_times
hltau_mscp_t = mscp_times
hltau_l1_a = serial_pnorms
hltau_l1p_a = combined_pnorms
hltau_msc_a = msc_pnorms
hltau_mscp_a = combined_mscp_pnorms

# %% [markdown]
# ### Serial breakdown

# %%
for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_serial_deconv_1500 += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
hltau_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### ms clean breakdown

# %%
for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_msclean_deconv_1500 += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
hltau_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_parallel_breakdown_data):
    vl_parallel_breakdown_data[i] = list(map(float, lst))

vl_weights_timings = vl_parallel_breakdown_data[1]
vl_psf_timings = vl_parallel_breakdown_data[2]
vl_wait_timings = vl_parallel_breakdown_data[3]
vl_mc_timings = vl_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_weights_timings[0], 0, 0, 0, 0, sum(vl_weights_timings[1:])])
timings.append([vl_psf_timings[0], vl_psf_timings[3], 0, 0, 0, sum(vl_psf_timings[1:2]) + vl_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv_1500 += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
hltau_timings_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_parallel_breakdown_data):
    vh_parallel_breakdown_data[i] = list(map(float, lst))

vh_weights_timings = vh_parallel_breakdown_data[1]
vh_psf_timings = vh_parallel_breakdown_data[2]
vh_wait_timings = vh_parallel_breakdown_data[3]
vh_mc_timings = vh_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_weights_timings[0], 0, 0, 0, 0, sum(vh_weights_timings[1:])])
timings.append([vh_psf_timings[0], vh_psf_timings[3], 0, 0, 0, sum(vh_psf_timings[1:3]) + vh_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv_1500 += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
hltau_timings_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_mscp_breakdown_data):
    vl_mscp_breakdown_data[i] = list(map(float, lst))

vl_mscp_weights_timings = vl_mscp_breakdown_data[1]
vl_mscp_psf_timings = vl_mscp_breakdown_data[2]
vl_mscp_wait_timings = vl_mscp_breakdown_data[3]
vl_mscp_mc_timings = vl_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_mscp_weights_timings[0], 0, 0, 0, 0, sum(vl_mscp_weights_timings[1:])])
timings.append([vl_mscp_psf_timings[0], vl_mscp_psf_timings[3], 0, 0, 0, sum(vl_mscp_psf_timings[1:2]) + vl_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
hltau_timings_mscp_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_mscp_breakdown_data):
    vh_mscp_breakdown_data[i] = list(map(float, lst))

vh_mscp_weights_timings = vh_mscp_breakdown_data[1]
vh_mscp_psf_timings = vh_mscp_breakdown_data[2]
vh_mscp_wait_timings = vh_mscp_breakdown_data[3]
vh_mscp_mc_timings = vh_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_mscp_weights_timings[0], 0, 0, 0, 0, sum(vh_mscp_weights_timings[1:])])
timings.append([vh_mscp_psf_timings[0], vh_mscp_psf_timings[3], 0, 0, 0, sum(vh_mscp_psf_timings[1:2]) + vh_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
hltau_timings_mscp_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Results for Cygnus A dataset
# #### Telescope Configuration: VLA all 4 configurations
# #### Frequency Bands: 1.9885GHz - 2.1165GHz, 2MHz width per channel, S-Band (first spectral window of 8, each has 64 channels)
# #### RA and DEC: (38.42, 57.25)
# #### $\text{V}_\mathcal{L}$ size: 41645824
# #### $\text{V}_\mathcal{H}$ size: 41828032
# #### $\text{V}$ size:  82246592
# #### $\ell$: 40
# #### $\delta$: 1
# #### Angular Resolution: 0.0000006060171rad
# #### Pixel Resolution: 1728x1728

# %%
cyga_res_path = "../results/ri_parallelization_results/cyga/"

vl_parallel_breakdown_data = helpers.read_csv(cyga_res_path + "cyga_parallel/mc_timings_breakdown_0", separate_rows=True)
vh_parallel_breakdown_data = helpers.read_csv(cyga_res_path + "cyga_parallel/mc_timings_breakdown_1", separate_rows=True)
serial_breakdown_data = helpers.read_csv(cyga_res_path + "cyga_serial/mc_timings_breakdown", separate_rows=True)
msc_breakdown_data = helpers.read_csv(cyga_res_path + "cyga_msclean/mc_timings_breakdown", separate_rows=True)
vl_mscp_breakdown_data = helpers.read_csv(cyga_res_path + "cyga_msclean_p/mc_timings_breakdown_0", separate_rows=True)
vh_mscp_breakdown_data = helpers.read_csv(cyga_res_path + "cyga_msclean_p/mc_timings_breakdown_1", separate_rows=True)

dirty = helpers.readFits(cyga_res_path + "cyga_serial/residual_0.fits")
helpers.plotNImages([dirty], [""], cmap="turbo", output_file="../figures/pCYGAdirty.pdf", hide_ticks=True)

compute_residuals = False
compute_jacknifed_residual = False
calculate_pvals = False
compute_weighted_combined = False

# %%
serial_times_sep = helpers.read_csv(cyga_res_path + "cyga_serial/mc_timings")
serial_times = []
serial_residuals = []
serial_pnorms = []

msc_times_sep = helpers.read_csv(cyga_res_path + "cyga_msclean/mc_timings")
msc_times = []
msc_residuals = []
msc_pnorms = []

parallel_times_sep = helpers.read_csv(cyga_res_path + "cyga_parallel/mc_timings")
parallel_times = []
vl_residuals = []
vh_residuals = []
combined_residuals = []
combined_weighted_residuals = []
vl_pnorms = []
vh_pnorms = []
combined_pnorms = []
combined_weighted_pnorms = []

mscp_times_sep = helpers.read_csv(cyga_res_path + "cyga_msclean_p/mc_timings")
mscp_times = []
vl_mscp_residuals = []
vh_mscp_residuals = []
combined_mscp_residuals = []
combined_mscp_weighted_residuals = []
vl_mscp_pnorms = []
vh_mscp_pnorms = []
combined_mscp_pnorms = []
combined_mscp_weighted_pnorms = []

if compute_jacknifed_residual:
    if weight_grid is None:
        weight_grid, model = helpers.compute_weights_griddata_by_channel("../../cyg_a/cygnus_a_allconfig_calib.ms", \
                                1728, 0.0000006060171, 0, 63, [0])
    jk_resid = helpers.compute_jackknifed_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                             1728, 0.0000006060171, "uniform", 0, weight_grid, 0, 63, [0])
    helpers.write_nparr_to_fits(jk_resid.pixels.data, cyga_res_path + "cyga_parallel/jacknifed_resid.fits")
    
jackknifed = helpers.readFits(cyga_res_path + "cyga_parallel/jacknifed_resid.fits")
jackknifed_resid = numpy.linalg.norm(jackknifed)

init_resid_img = helpers.readFits(cyga_res_path + "cyga_serial/residual_0.fits")
init_resid_norm = numpy.linalg.norm(init_resid_img)

#For serial
curr_deconv = None
time_acc = 0
for i in range(0, num_mc + 1):
    curr_deconv_img = helpers.readFits(cyga_res_path + "cyga_serial/deconvolved_" + str(i) + ".fits")
    curr_resid_img = helpers.readFits(cyga_res_path + "cyga_serial/residual_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(serial_times_sep[i])
    
    if calculate_pvals:
        serial_pvals, serial_pnorm = helpers.t_test_image(curr_resid_img, jackknifed, 5)
        helpers.write_nparr_to_fits(serial_pvals, cyga_res_path + "cyga_serial/serial_pvals_" + str(i) + ".fits")
    
    serial_pvals = helpers.readFits(cyga_res_path + "cyga_serial/serial_pvals_" + str(i) + ".fits")

    serial_pnorms.append(numpy.linalg.norm(serial_pvals))

    serial_residuals.append(numpy.linalg.norm(curr_resid_img))
    serial_times.append(time_acc)
    
#For msclean
curr_deconv = None
time_acc = 0
for i in range(0, num_mc + 1):
    curr_deconv_img = helpers.readFits(cyga_res_path + "cyga_msclean/deconvolved_" + str(i) + ".fits")
    curr_resid_img = helpers.readFits(cyga_res_path + "cyga_msclean/residual_" + str(i) + ".fits")
    if curr_deconv is None:
        curr_deconv = curr_deconv_img
    else:
        curr_deconv += curr_deconv_img
        
    time_acc += float(msc_times_sep[i])
    
    if calculate_pvals:
        msc_pvals, msc_pnorm = helpers.t_test_image(curr_resid_img, jackknifed, 5)
        helpers.write_nparr_to_fits(msc_pvals, cyga_res_path + "cyga_msclean/msc_pvals_" + str(i) + ".fits")
    
    msc_pvals = helpers.readFits(cyga_res_path + "cyga_msclean/msc_pvals_" + str(i) + ".fits")

    msc_pnorms.append(numpy.linalg.norm(msc_pvals))

    msc_residuals.append(numpy.linalg.norm(curr_resid_img))
    msc_times.append(time_acc)

#parallel l1
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = 0

weight_grid = model = None

if compute_residuals:
    weight_grid, model = helpers.compute_weights_griddata_by_channel("../../cyg_a/cygnus_a_allconfig_calib.ms", \
                                1728, 0.0000006060171, 0, 63, [0])
    
init_pvals = helpers.readFits(cyga_res_path + "cyga_serial/serial_pvals_0.fits")
init_pnorm = numpy.linalg.norm(init_pvals)

vl_residuals.append(init_resid_norm)
vh_residuals.append(init_resid_norm)
combined_residuals.append(init_resid_norm)
vl_pnorms.append(init_pnorm)
vh_pnorms.append(init_pnorm)
combined_pnorms.append(init_pnorm)
combined_weighted_pnorms.append(init_pnorm)
time_acc += float(parallel_times_sep[0])
parallel_times.append(time_acc)


for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(cyga_res_path + "cyga_parallel/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(cyga_res_path + "cyga_parallel/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(parallel_times_sep[i+1])
    
    if compute_weighted_combined:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        
        helpers.write_nparr_to_fits(curr_deconv_weighted, cyga_res_path + "cyga_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(cyga_res_path + "cyga_parallel/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(cyga_res_path + "cyga_parallel/deconv_combined_" + str(i) + ".fits")
        
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_weighted
        combined_residual_weighted = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, cyga_res_path + "cyga_parallel/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, cyga_res_path + "cyga_parallel/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, cyga_res_path + "cyga_parallel/combined_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual_weighted.pixels.data, cyga_res_path + "cyga_parallel/combined_fullresid_weighted_" + str(i) + ".fits")

    vl_residual = helpers.readFits(cyga_res_path + "cyga_parallel/vl_fullresid_" + str(i) + ".fits")
    vh_residual = helpers.readFits(cyga_res_path + "cyga_parallel/vh_fullresid_" + str(i) + ".fits")
    combined_residual = helpers.readFits(cyga_res_path + "cyga_parallel/combined_fullresid_" + str(i) + ".fits")
    combined_residual_weighted = helpers.readFits(cyga_res_path + "cyga_parallel/combined_fullresid_weighted_" + str(i) + ".fits")
    
    if calculate_pvals:
        #vl_pvals, vl_pnorm = helpers.t_test_image(vl_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vl_pvals, cyga_res_path + "cyga_parallel/vl_pvals_" + str(i) + ".fits")
        #vh_pvals, vh_pnorm = helpers.t_test_image(vh_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vh_pvals, cyga_res_path + "cyga_parallel/vh_pvals_" + str(i) + ".fits")
        combined_pvals, combined_pnorm = helpers.t_test_image(combined_residual, jackknifed, 5)
        helpers.write_nparr_to_fits(combined_pvals, cyga_res_path + "cyga_parallel/combined_pvals_" + str(i) + ".fits")
        #combined_weighted_pvals, combined_weighted_pnorm = helpers.t_test_image(combined_residual_weighted, jackknifed, 5)
        #helpers.write_nparr_to_fits(combined_weighted_pvals, cyga_res_path + "cyga_parallel/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_pvals = helpers.readFits(cyga_res_path + "cyga_parallel/vl_pvals_" + str(i) + ".fits")
    vh_pvals = helpers.readFits(cyga_res_path + "cyga_parallel/vh_pvals_" + str(i) + ".fits")
    combined_pvals = helpers.readFits(cyga_res_path + "cyga_parallel/combined_pvals_" + str(i) + ".fits")
    combined_weighted_pvals = helpers.readFits(cyga_res_path + "cyga_parallel/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_residuals.append(numpy.linalg.norm(vl_residual))
    vh_residuals.append(numpy.linalg.norm(vh_residual))
    combined_residuals.append(numpy.linalg.norm(combined_residual))
    combined_weighted_residuals.append(numpy.linalg.norm(combined_residual_weighted))
    
    vl_pnorms.append(numpy.linalg.norm(vl_pvals))
    vh_pnorms.append(numpy.linalg.norm(vh_pvals))
    combined_pnorms.append(numpy.linalg.norm(combined_pvals))
    combined_weighted_pnorms.append(numpy.linalg.norm(combined_weighted_pvals))
    
    parallel_times.append(time_acc)
    
    
#parallel msclean
curr_deconv_vl = None
curr_deconv_vh = None
time_acc = 0

vl_mscp_residuals.append(init_resid_norm)
vh_mscp_residuals.append(init_resid_norm)
combined_mscp_residuals.append(init_resid_norm)
vl_mscp_pnorms.append(init_pnorm)
vh_mscp_pnorms.append(init_pnorm)
combined_mscp_pnorms.append(init_pnorm)
combined_mscp_weighted_pnorms.append(init_pnorm)
time_acc += float(parallel_times_sep[0])
mscp_times.append(time_acc)

for i in range(0, num_mc):
    curr_deconv_vl_img = helpers.readFits(cyga_res_path + "cyga_msclean_p/deconv_vl_" + str(i) + ".fits")
    curr_deconv_vh_img = helpers.readFits(cyga_res_path + "cyga_msclean_p/deconv_vh_" + str(i) + ".fits")
    if curr_deconv_vl is None:
        curr_deconv_vl = curr_deconv_vl_img
        curr_deconv_vh = curr_deconv_vh_img
    else:
        curr_deconv_vl += curr_deconv_vl_img
        curr_deconv_vh += curr_deconv_vh_img
        
    time_acc += float(mscp_times_sep[i+1]) - float(parallel_times_sep[0]) if i == 0 else float(mscp_times_sep[i+1])
    
    if compute_weighted_combined:
        weight_vl = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vl, 5))
        weight_vh = 1 / numpy.linalg.norm(helpers.compute_windowed_var(curr_deconv_vh, 5))

        weight_total = weight_vl + weight_vh
        weight_vl /= weight_total
        weight_vh /= weight_total

        curr_deconv_weighted = weight_vl * curr_deconv_vl + weight_vh * curr_deconv_vh
        
        helpers.write_nparr_to_fits(curr_deconv_weighted, cyga_res_path + "cyga_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    
    curr_deconv_weighted = helpers.readFits(cyga_res_path + "cyga_msclean_p/deconv_weighted_combined_" + str(i) + ".fits")
    curr_deconv_combined = helpers.readFits(cyga_res_path + "cyga_msclean_p/deconv_combined_" + str(i) + ".fits")
        
    if compute_residuals:
        model.pixels.data[0, 0, :, :] = curr_deconv_vl
        vl_residual = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_vh
        vh_residual = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_combined
        combined_residual = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        model.pixels.data[0, 0, :, :] = curr_deconv_weighted
        combined_residual_weighted = helpers.compute_residual_bychannel(model, "../../cyg_a/cygnus_a_allconfig_calib.ms",\
                                                 1728, 0.0000006060171, "uniform", 0, weight_grid, \
                                                 0, 63, [0])
        
        helpers.write_nparr_to_fits(vl_residual.pixels.data, cyga_res_path + "cyga_msclean_p/vl_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(vh_residual.pixels.data, cyga_res_path + "cyga_msclean_p/vh_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual.pixels.data, cyga_res_path + "cyga_msclean_p/combined_fullresid_" + str(i) + ".fits")
        helpers.write_nparr_to_fits(combined_residual_weighted.pixels.data, cyga_res_path + "cyga_msclean_p/combined_fullresid_weighted_" + str(i) + ".fits")

    vl_residual = helpers.readFits(cyga_res_path + "cyga_msclean_p/vl_fullresid_" + str(i) + ".fits")
    vh_residual = helpers.readFits(cyga_res_path + "cyga_msclean_p/vh_fullresid_" + str(i) + ".fits")
    combined_residual = helpers.readFits(cyga_res_path + "cyga_msclean_p/combined_fullresid_" + str(i) + ".fits")
    combined_residual_weighted = helpers.readFits(cyga_res_path + "cyga_msclean_p/combined_fullresid_weighted_" + str(i) + ".fits")
    
    if calculate_pvals:
        #vl_pvals, vl_pnorm = helpers.t_test_image(vl_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vl_pvals, cyga_res_path + "cyga_msclean_p/vl_pvals_" + str(i) + ".fits")
        #vh_pvals, vh_pnorm = helpers.t_test_image(vh_residual, jackknifed, 5)
        #helpers.write_nparr_to_fits(vh_pvals, cyga_res_path + "cyga_msclean_p/vh_pvals_" + str(i) + ".fits")
        combined_pvals, combined_pnorm = helpers.t_test_image(combined_residual, jackknifed, 5)
        helpers.write_nparr_to_fits(combined_pvals, cyga_res_path + "cyga_msclean_p/combined_pvals_" + str(i) + ".fits")
        #combined_weighted_pvals, combined_weighted_pnorm = helpers.t_test_image(combined_residual_weighted, jackknifed, 5)
        #helpers.write_nparr_to_fits(combined_weighted_pvals, cyga_res_path + "cyga_msclean_p/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_pvals = helpers.readFits(cyga_res_path + "cyga_msclean_p/vl_pvals_" + str(i) + ".fits")
    vh_pvals = helpers.readFits(cyga_res_path + "cyga_msclean_p/vh_pvals_" + str(i) + ".fits")
    combined_pvals = helpers.readFits(cyga_res_path + "cyga_msclean_p/combined_pvals_" + str(i) + ".fits")
    combined_weighted_pvals = helpers.readFits(cyga_res_path + "cyga_msclean_p/combined_weighted_pvals_" + str(i) + ".fits")
    
    vl_mscp_residuals.append(numpy.linalg.norm(vl_residual))
    vh_mscp_residuals.append(numpy.linalg.norm(vh_residual))
    combined_mscp_residuals.append(numpy.linalg.norm(combined_residual))
    combined_mscp_weighted_residuals.append(numpy.linalg.norm(combined_residual_weighted))
    
    vl_mscp_pnorms.append(numpy.linalg.norm(vl_pvals))
    vh_mscp_pnorms.append(numpy.linalg.norm(vh_pvals))
    combined_mscp_pnorms.append(numpy.linalg.norm(combined_pvals))
    combined_mscp_weighted_pnorms.append(numpy.linalg.norm(combined_weighted_pvals))
    
    mscp_times.append(time_acc)
    
    
plt.plot(serial_times, serial_pnorms, c='crimson', label="serial $\ell^1$ recon", lw=3, marker='o', markersize=10)
plt.plot(msc_times, msc_pnorms, c='darkblue', label="serial ms-clean recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, vl_psnrs, c='teal', label="${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vh_psnrs, c='purple', label="${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(parallel_times, combined_pnorms, c='coral', label="parallel $\ell^1$ recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combined_weighted_psnrs, c='darkorange', label="combined weighted parallel recon", lw=2, marker='o')

#plt.plot(parallel_times, vlmsc_psnrs, c='powderblue', label="msclean ${V}_\mathcal{L}$ recon", lw=2, marker='o')
#plt.plot(parallel_times, vhmsc_psnrs, c='plum', label="msclean ${V}_\mathcal{H}$ recon", lw=2, marker='o')
plt.plot(mscp_times, combined_mscp_pnorms, c='dodgerblue', label="parallel ms-clean recon", lw=3, marker='o', markersize=10)
#plt.plot(parallel_times, combinedmsc_weighted_psnrs, c='moccasin', label="msclean combined weighted parallel recon", lw=2, marker='o')
plt.xlabel("Time (s)", fontsize=20)
plt.ylabel("S/N (dB)", fontsize=20)
#plt.yscale('log')
#plt.legend(loc="lower right", fontsize=16)
plt.locator_params(nbins=5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.savefig("../interleaved_parallelization_prototype/figures/cyga_timeacc.pdf", pad_inches=0.0, bbox_inches='tight')

cyga_l1_t = serial_times
cyga_l1p_t = parallel_times
cyga_msc_t = msc_times
cyga_mscp_t = mscp_times
cyga_l1_a = serial_pnorms
cyga_l1p_a = combined_pnorms
cyga_msc_a = msc_pnorms
cyga_mscp_a = combined_mscp_pnorms

# %% [markdown]
# ### Serial breakdown

# %%
for i, lst in enumerate(serial_breakdown_data):
    serial_breakdown_data[i] = list(map(float, lst))

serial_weights_timings = serial_breakdown_data[1]
serial_psf_timings = serial_breakdown_data[2]

serial_mc_timings = serial_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(serial_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([serial_weights_timings[0], 0, 0, 0, sum(serial_weights_timings[1:])])
timings.append([serial_psf_timings[0], serial_psf_timings[3], 0, 0, sum(serial_psf_timings[1:3]) + serial_psf_timings[4]])

for i, curr_mc_timings in enumerate(serial_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_serial_deconv_1728 += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
cyga_timings_serial = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean breakdown

# %%
for i, lst in enumerate(msc_breakdown_data):
    msc_breakdown_data[i] = list(map(float, lst))

msc_weights_timings = msc_breakdown_data[1]
msc_psf_timings = msc_breakdown_data[2]

msc_mc_timings = msc_breakdown_data[3:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(msc_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([msc_weights_timings[0], 0, 0, 0, sum(msc_weights_timings[1:])])
timings.append([msc_psf_timings[0], msc_psf_timings[3], 0, 0, sum(msc_psf_timings[1:3]) + msc_psf_timings[4]])

for i, curr_mc_timings in enumerate(msc_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[1:4]) + curr_mc_timings[5] + curr_mc_timings[7]
    timings.append([curr_mc_timings[0], curr_mc_timings[6], curr_mc_timings[4], curr_mc_timings[8], other_timings])
    average_msclean_deconv_1728 += curr_mc_timings[8]
    
for i, curr_breakdown in enumerate(breakdowns):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])
    
    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
cyga_timings_msc = total_timings(timings, breakdowns)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_parallel_breakdown_data):
    vl_parallel_breakdown_data[i] = list(map(float, lst))

vl_weights_timings = vl_parallel_breakdown_data[1]
vl_psf_timings = vl_parallel_breakdown_data[2]
vl_wait_timings = vl_parallel_breakdown_data[3]
vl_mc_timings = vl_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_weights_timings[0], 0, 0, 0, 0, sum(vl_weights_timings[1:])])
timings.append([vl_psf_timings[0], vl_psf_timings[3], 0, 0, 0, sum(vl_psf_timings[1:2]) + vl_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv_1728 += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
cyga_timings_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_parallel_breakdown_data):
    vh_parallel_breakdown_data[i] = list(map(float, lst))

vh_weights_timings = vh_parallel_breakdown_data[1]
vh_psf_timings = vh_parallel_breakdown_data[2]
vh_wait_timings = vh_parallel_breakdown_data[3]
vh_mc_timings = vh_parallel_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_weights_timings[0], 0, 0, 0, 0, sum(vh_weights_timings[1:])])
timings.append([vh_psf_timings[0], vh_psf_timings[3], 0, 0, 0, sum(vh_psf_timings[1:2]) + vh_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv_1728 += curr_mc_timings[9]
    
    print(str(curr_mc_timings[2:5]) + " " + str(curr_mc_timings[6]) + " " + str(curr_mc_timings[8]))
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
cyga_timings_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()
# Out:
# [5.1697838306427, 5.246603012084961, 0.5353081226348877] 0.7746434211730957 0.24892354011535645
# [5.11548638343811, 5.270111083984375, 0.5327353477478027] 0.7795577049255371 0.24933099746704102
# [5.129894971847534, 5.2877185344696045, 0.5396018028259277] 0.7737700939178467 0.25261592864990234
# [5.078362941741943, 5.252731561660767, 0.5317459106445312] 0.772355318069458 0.2509310245513916
# [5.063680648803711, 5.215118408203125, 0.5320978164672852] 0.7704768180847168 0.250150203704834

# %% [markdown]
# ### msclean parallel breakdown $\text{V}_\mathcal{L}$ node

# %%
for i, lst in enumerate(vl_mscp_breakdown_data):
    vl_mscp_breakdown_data[i] = list(map(float, lst))

vl_mscp_weights_timings = vl_mscp_breakdown_data[1]
vl_mscp_psf_timings = vl_mscp_breakdown_data[2]
vl_mscp_wait_timings = vl_mscp_breakdown_data[3]
vl_mscp_mc_timings = vl_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vl_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vl_mscp_weights_timings[0], 0, 0, 0, 0, sum(vl_mscp_weights_timings[1:])])
timings.append([vl_mscp_psf_timings[0], vl_mscp_psf_timings[3], 0, 0, 0, sum(vl_mscp_psf_timings[1:2]) + vl_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vl_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
cyga_timings_mscp_vl = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### msclean parallel $\text{V}_\mathcal{H}$ breakdown

# %%
for i, lst in enumerate(vh_mscp_breakdown_data):
    vh_mscp_breakdown_data[i] = list(map(float, lst))

vh_mscp_weights_timings = vh_mscp_breakdown_data[1]
vh_mscp_psf_timings = vh_mscp_breakdown_data[2]
vh_mscp_wait_timings = vh_mscp_breakdown_data[3]
vh_mscp_mc_timings = vh_mscp_breakdown_data[4:]

width = 0.5

labels = [
    "Weights",
    "PSF"
]
    
bottom = numpy.zeros(len(vh_mscp_mc_timings) + 2)
    
fig, ax = plt.subplots()

timings = []
timings.append([vh_mscp_weights_timings[0], 0, 0, 0, 0, sum(vh_mscp_weights_timings[1:])])
timings.append([vh_mscp_psf_timings[0], vh_mscp_psf_timings[3], 0, 0, 0, sum(vh_mscp_psf_timings[1:2]) + vh_mscp_psf_timings[4]])

for i, curr_mc_timings in enumerate(vh_mscp_mc_timings):
    labels.append("MC " + str(i))
    other_timings = sum(curr_mc_timings[2:5]) + curr_mc_timings[6] + curr_mc_timings[8]
    timings.append([curr_mc_timings[1], curr_mc_timings[7], curr_mc_timings[5], curr_mc_timings[9], \
                    curr_mc_timings[0] + curr_mc_timings[10], other_timings])
    average_parallel_deconv += curr_mc_timings[9]
    
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_breakdown_timing = []
    for curr_timing in timings:
        curr_breakdown_timing.append(curr_timing[i])

    p = ax.bar(labels, curr_breakdown_timing, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_breakdown_timing
    
cyga_timings_mscp_vh = total_timings(timings, breakdowns_parallel)
    
ax.legend(loc="upper right")
plt.show()

# %%
labels=["$L1$", "msc", "p-$L^1V_\mathcal{L}$", "p-$L1V_\mathcal{H}$", "p-msc$V_\mathcal{L}$", "p-msc$V_\mathcal{H}$"]
matplotlib.rcParams['figure.figsize'] = [8, 5]

# %%
fig, ax = plt.subplots()

bottom = numpy.zeros(6)

for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, sgra_timings_vl[i], sgra_timings_vh[i], sgra_timings_mscp_vl[i], sgra_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [sgra_timings_serial[i - 1], sgra_timings_msc[i - 1], sgra_timings_vl[i], sgra_timings_vh[i], sgra_timings_mscp_vl[i], sgra_timings_mscp_vh[i]]
    else:
        curr_timings = [sgra_timings_serial[i], sgra_timings_msc[i], sgra_timings_vl[i], sgra_timings_vh[i], sgra_timings_mscp_vl[i], sgra_timings_mscp_vh[i]]
    
    p = ax.bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings

ax.legend(loc="upper right", fontsize=14)
plt.ylabel("Time (s)", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.locator_params(axis='y', nbins=6)

plt.savefig("../interleaved_parallelization_prototype/figures/sgra_breakdown.pdf", pad_inches=0.0, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

bottom = numpy.zeros(6)

for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, sgrb_timings_vl[i], sgrb_timings_vh[i], sgrb_timings_mscp_vl[i], sgrb_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [sgrb_timings_serial[i - 1], sgrb_timings_msc[i - 1], sgrb_timings_vl[i], sgrb_timings_vh[i], sgrb_timings_mscp_vl[i], sgrb_timings_mscp_vh[i]]
    else:
        curr_timings = [sgrb_timings_serial[i], sgrb_timings_msc[i], sgrb_timings_vl[i], sgrb_timings_vh[i], sgrb_timings_mscp_vl[i], sgrb_timings_mscp_vh[i]]
        
    p = ax.bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings

ax.legend(loc="upper right", fontsize=15, ncol=2)
plt.ylabel("Time (s)", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.locator_params(axis='y', nbins=6)

plt.savefig("../interleaved_parallelization_prototype/figures/sgrb_breakdown.pdf", pad_inches=0.0, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

bottom = numpy.zeros(6)

for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, sgrc_timings_vl[i], sgrc_timings_vh[i], sgrc_timings_mscp_vl[i], sgrc_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [sgrc_timings_serial[i - 1], sgrc_timings_msc[i - 1], sgrc_timings_vl[i], sgrc_timings_vh[i], sgrc_timings_mscp_vl[i], sgrc_timings_mscp_vh[i]]
    else:
        curr_timings = [sgrc_timings_serial[i], sgrc_timings_msc[i], sgrc_timings_vl[i], sgrc_timings_vh[i], sgrc_timings_mscp_vl[i], sgrc_timings_mscp_vh[i]]
        
    p = ax.bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings

#ax.legend(loc="upper right", fontsize=13)
plt.ylabel("Time (s)", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.locator_params(axis='y', nbins=6)
plt.savefig("../interleaved_parallelization_prototype/figures/sgrc_breakdown.pdf", pad_inches=0.0, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

bottom = numpy.zeros(6)

for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, hltau_timings_vl[i], hltau_timings_vh[i], hltau_timings_mscp_vl[i], hltau_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [hltau_timings_serial[i - 1], hltau_timings_msc[i - 1], hltau_timings_vl[i], hltau_timings_vh[i], hltau_timings_mscp_vl[i], hltau_timings_mscp_vh[i]]
    else:
        curr_timings = [hltau_timings_serial[i], hltau_timings_msc[i], hltau_timings_vl[i], hltau_timings_vh[i], hltau_timings_mscp_vl[i], hltau_timings_mscp_vh[i]]
        
    p = ax.bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings

#ax.legend(loc="upper right", fontsize=13)
plt.ylabel("Time (s)", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.locator_params(axis='y', nbins=6)
plt.savefig("../interleaved_parallelization_prototype/figures/hltau_breakdown.pdf", pad_inches=0.0, bbox_inches='tight')

# %%
fig, ax = plt.subplots()

bottom = numpy.zeros(6)

for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, cyga_timings_vl[i], cyga_timings_vh[i], cyga_timings_mscp_vl[i], cyga_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [cyga_timings_serial[i - 1], cyga_timings_msc[i - 1], cyga_timings_vl[i], cyga_timings_vh[i], cyga_timings_mscp_vl[i], cyga_timings_mscp_vh[i]]
    else:
        curr_timings = [cyga_timings_serial[i], cyga_timings_msc[i], cyga_timings_vl[i], cyga_timings_vh[i], cyga_timings_mscp_vl[i], cyga_timings_mscp_vh[i]]

    p = ax.bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings

#ax.legend(loc="upper right", fontsize=13)
plt.ylabel("Time (s)", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=13)
plt.locator_params(axis='y', nbins=6)
plt.savefig("../interleaved_parallelization_prototype/figures/cyga_breakdown.pdf", pad_inches=0.0, bbox_inches='tight')

# %% [markdown]
# ### Average deconvolution processing times

# %%
average_parallel_deconv /= (3 * 5 * 2)
average_serial_deconv /= (3 * 5)
average_msclean_deconv /= (3 * 5)

average_parallel_deconv_1500 /= (5 * 2)
average_serial_deconv_1500 /= (5)
average_msclean_deconv_1500 /= (5)

average_parallel_deconv_1728 /= (5 * 2)
average_serial_deconv_1728 /= (5)
average_msclean_deconv_1728 /= (5)

print("512x512:")
print("Parallel: " + str(average_parallel_deconv))
print("Serial: " + str(average_serial_deconv))
print("ms CLEAN: " + str(average_msclean_deconv))

print("1500x1500:")
print("Parallel: " + str(average_parallel_deconv_1500))
print("Serial: " + str(average_serial_deconv_1500))
print("ms CLEAN: " + str(average_msclean_deconv_1500))

print("1728x1728:")
print("Parallel: " + str(average_parallel_deconv_1728))
print("Serial: " + str(average_serial_deconv_1728))
print("ms CLEAN: " + str(average_msclean_deconv_1728))
# Out:
# 512x512:
# Parallel: 197.06742398738862
# Serial: 35.52873862584432
# ms CLEAN: 22.224849239985147
# 1500x1500:
# Parallel: 230.02272555828094
# Serial: 167.20080213546754
# ms CLEAN: 90.17081170082092
# 1728x1728:
# Parallel: 317.10500705242157
# Serial: 227.72237792015076
# ms CLEAN: 430.1438313007355

# %%
matplotlib.rcParams['figure.figsize'] = [14, 3]

fig, axs = plt.subplots(1, 4)


axs[0].plot(sgrb_l1_t, sgrb_l1_a, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
axs[0].plot(sgrb_l1p_t, sgrb_l1p_a, c='darkblue', label="p-$L1$", lw=3, marker='o', markersize=10)
axs[0].plot(sgrb_msc_t, sgrb_msc_a, c='coral', label="msc", lw=3, marker='o', markersize=10)
axs[0].plot(sgrb_mscp_t, sgrb_mscp_a, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)
axs[0].set_title('Sgr B2', fontsize=14)
axs[0].legend(loc="lower right", fontsize=10)
axs[0].set_ylabel('S/N (dB)', fontsize=12)
axs[0].set_xlabel('Time (s)', fontsize=12)


axs[1].plot(sgrc_l1_t, sgrc_l1_a, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
axs[1].plot(sgrc_l1p_t, sgrc_l1p_a, c='darkblue', label="p-$L1$", lw=3, marker='o', markersize=10)
axs[1].plot(sgrc_msc_t, sgrc_msc_a, c='coral', label="msc", lw=3, marker='o', markersize=10)
axs[1].plot(sgrc_mscp_t, sgrc_mscp_a, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)
axs[1].set_title('Sgr C', fontsize=14)
axs[1].set_ylabel('S/N (dB)', fontsize=12)
axs[1].set_xlabel('Time (s)', fontsize=12)


axs[2].plot(hltau_l1_t, hltau_l1_a, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
axs[2].plot(hltau_l1p_t, hltau_l1p_a, c='darkblue', label="p-$L1$", lw=3, marker='o', markersize=10)
axs[2].plot(hltau_msc_t, hltau_msc_a, c='coral', label="msc", lw=3, marker='o', markersize=10)
axs[2].plot(hltau_mscp_t, hltau_mscp_a, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)
axs[2].set_title('HL Tau', fontsize=14)
axs[2].set_ylabel('$\|W(r, n)_5\|_2$', fontsize=12)
axs[2].set_xlabel('Time (s)', fontsize=12)

axs[3].plot(cyga_l1_t, cyga_l1_a, c='crimson', label="$L1$", lw=3, marker='o', markersize=10)
axs[3].plot(cyga_l1p_t, cyga_l1p_a, c='darkblue', label="p-$L1$", lw=3, marker='o', markersize=10)
axs[3].plot(cyga_msc_t, cyga_msc_a, c='coral', label="msc", lw=3, marker='o', markersize=10)
axs[3].plot(cyga_mscp_t, cyga_mscp_a, c='dodgerblue', label="p-msc", lw=3, marker='o', markersize=10)
axs[3].set_title('Cyg A', fontsize=14)
axs[3].set_ylabel('$\|W(r, n)_5\|_2$', fontsize=12)
axs[3].set_xlabel('Time (s)', fontsize=12)

fig.tight_layout()

fig.savefig("../interleaved_parallelization_prototype/figures/timeacc.pdf", pad_inches=0.0, bbox_inches='tight')

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]

fig, axes = plt.subplots(2, 2)

bottom = numpy.zeros(6)

for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, sgrb_timings_vl[i], sgrb_timings_vh[i], sgrb_timings_mscp_vl[i], sgrb_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [sgrb_timings_serial[i - 1], sgrb_timings_msc[i - 1], sgrb_timings_vl[i], sgrb_timings_vh[i], sgrb_timings_mscp_vl[i], sgrb_timings_mscp_vh[i]]
    else:
        curr_timings = [sgrb_timings_serial[i], sgrb_timings_msc[i], sgrb_timings_vl[i], sgrb_timings_vh[i], sgrb_timings_mscp_vl[i], sgrb_timings_mscp_vh[i]]
        
    p = axes[0, 0].bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings
    
axes[0, 0].set_title('Sgr B2', fontsize=14)
axes[0, 0].legend(loc="upper right", fontsize=10, ncol=2)
axes[0, 0].set_ylabel('Time (s)', fontsize=12)

bottom = numpy.zeros(6)
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, sgrc_timings_vl[i], sgrc_timings_vh[i], sgrc_timings_mscp_vl[i], sgrc_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [sgrc_timings_serial[i - 1], sgrc_timings_msc[i - 1], sgrc_timings_vl[i], sgrc_timings_vh[i], sgrc_timings_mscp_vl[i], sgrc_timings_mscp_vh[i]]
    else:
        curr_timings = [sgrc_timings_serial[i], sgrc_timings_msc[i], sgrc_timings_vl[i], sgrc_timings_vh[i], sgrc_timings_mscp_vl[i], sgrc_timings_mscp_vh[i]]
        
    p = axes[1, 0].bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings
    
axes[1, 0].set_title('Sgr C', fontsize=14)
axes[1, 0].set_ylabel('Time (s)', fontsize=12)

bottom = numpy.zeros(6)
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, hltau_timings_vl[i], hltau_timings_vh[i], hltau_timings_mscp_vl[i], hltau_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [hltau_timings_serial[i - 1], hltau_timings_msc[i - 1], hltau_timings_vl[i], hltau_timings_vh[i], hltau_timings_mscp_vl[i], hltau_timings_mscp_vh[i]]
    else:
        curr_timings = [hltau_timings_serial[i], hltau_timings_msc[i], hltau_timings_vl[i], hltau_timings_vh[i], hltau_timings_mscp_vl[i], hltau_timings_mscp_vh[i]]
        
    p = axes[0, 1].bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings

axes[0, 1].set_title('HL Tau', fontsize=14)
axes[0, 1].set_ylabel('Time (s)', fontsize=12)
    
bottom = numpy.zeros(6)
for i, curr_breakdown in enumerate(breakdowns_parallel):
    curr_timings = None
    if i == 4:
        curr_timings = [0, 0, cyga_timings_vl[i], cyga_timings_vh[i], cyga_timings_mscp_vl[i], cyga_timings_mscp_vh[i]]
    elif i > 4:
        curr_timings = [cyga_timings_serial[i - 1], cyga_timings_msc[i - 1], cyga_timings_vl[i], cyga_timings_vh[i], cyga_timings_mscp_vl[i], cyga_timings_mscp_vh[i]]
    else:
        curr_timings = [cyga_timings_serial[i], cyga_timings_msc[i], cyga_timings_vl[i], cyga_timings_vh[i], cyga_timings_mscp_vl[i], cyga_timings_mscp_vh[i]]
        
    p = axes[1, 1].bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings
    
axes[1, 1].set_title('Cyg A', fontsize=14)
axes[1, 1].set_ylabel('Time (s)', fontsize=12)

plt.savefig("../interleaved_parallelization_prototype/figures/breakdown.pdf", pad_inches=0.0, bbox_inches='tight')

# %%
matplotlib.rcParams['figure.figsize'] = [6, 5]
labels=["SgrB2", "SgrC", "HLTau", "CygA"]

fig, ax = plt.subplots()

sgrb_timings_serial_norm = [x / sum(sgrb_timings_serial) * 100 for x in sgrb_timings_serial]
sgrc_timings_serial_norm = [x / sum(sgrc_timings_serial) * 100 for x in sgrc_timings_serial]
hltau_timings_serial_norm = [x / sum(hltau_timings_serial) * 100 for x in hltau_timings_serial]
cyga_timings_serial_norm = [x / sum(cyga_timings_serial) * 100 for x in cyga_timings_serial]

sgrb_timings_msc_norm = [x / sum(sgrb_timings_msc) * 100 for x in sgrb_timings_msc]
sgrc_timings_msc_norm = [x / sum(sgrc_timings_msc) * 100 for x in sgrc_timings_msc]
hltau_timings_msc_norm = [x / sum(hltau_timings_msc) * 100 for x in hltau_timings_msc]
cyga_timings_msc_norm = [x / sum(cyga_timings_msc) * 100 for x in cyga_timings_msc]

bottom = numpy.zeros(4)

ax.set_title('$L1$', fontsize=20)
ax.set_ylabel('Time (%)', fontsize=14)

for i, curr_breakdown in enumerate(breakdowns):
    curr_timings = [sgrb_timings_serial_norm[i],\
                    sgrc_timings_serial_norm[i],\
                    hltau_timings_serial_norm[i],\
                    cyga_timings_serial_norm[i]]
    
    p = ax.bar(labels, curr_timings, width, label=curr_breakdown, bottom=bottom)
    bottom += curr_timings
    
ax.legend(loc="upper right", fontsize=10, ncol=2)
ax.set_ylim([0,130])
ax.set_yticks([0, 25, 50, 75, 100])
    
plt.savefig("../interleaved_parallelization_prototype/figures/breakdown_norm.pdf", pad_inches=0.0, bbox_inches='tight')
