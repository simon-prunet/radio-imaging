# %% [markdown]
# # Produce dirty image and psf, from a (rascil) FITS image, and an instrumental setup (baselines, frequencies, etc.)

# %%
from visibilities import *
from images import *
import matplotlib.pyplot as plt
import matplotlib
import numpy

import helpers

plt.set_loglevel("critical")
cmap='turbo'
matplotlib.rcParams['figure.figsize'] = [5, 5]

# %% [markdown]
# ### Generate visibilities based on antenna configuration, integration time, hour angle interval of observations, phase centre, frequencies etc.

# %%
gt_name = "SGRA"
config_name = "mid_aastar"

phasecentre = SkyCoord(ra=+56.0 * u.deg, dec=-35.0 * u.deg, frame='icrs', equinox='J2000')
ha_interval=(-1,1)

bandwidth = 1e6
frequencies = range(int(50*1e6), int(51*1e6), int(bandwidth))
bandwidths = [bandwidth] * len(frequencies)

vt = generate_visibilities(phasecentre,ha_interval,tel="MID_AASTAR", integration_time=120, frequencies=np.array(frequencies).astype(float), channel_bandwidths=np.array(bandwidths))
# Out:
# create_visibility: created 60 times
# create_visibility: 626400 rows, 0.033 GB
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:87: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'baselines' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   super().__init__(data_vars, coords=coords, attrs=attrs)

# %% [markdown]
# ### Plot uv coverage (if there aren't too many visibilities, otherwise this function takes too long and may crash)

# %%
if vt.vis.size < 1e7:
    matplotlib.rcParams['figure.figsize'] = [6, 5]
    plot_uvcoverage([vt])
# Out:
# There is no flagged visibility. Skip plotting flagged.
# /home/sunwang/.local/lib/python3.10/site-packages/xarray/core/dataarray.py:3099: DeprecationWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'baselines'} to avoid an error in the future.
#   ds = self._to_temp_dataset().drop_vars(names, errors=errors)

# %% [markdown]
# ### Fill visibilities amplitude from (Fourier plane values) of image in FITS file. Cell size corresponds to the (advised) pixel angular size in radians. Uses Nifty gridder.

# %%
num_pix = helpers.readFits('../data/' + gt_name + '_full_gt.fits').shape[0]

vt, cell_size, im = visibilities_from_image(vt,'../data/' + gt_name + '_full_gt.fits',return_cellsize=True,return_image=True,scale_factor=1.8)
# Out:
# advise_wide_field: (max_wavelength) Maximum wavelength 5.996 (meters)
# advise_wide_field: (min_wavelength) Minimum wavelength 5.996 (meters)
# advise_wide_field: (maximum_baseline) Maximum baseline 15882.4 (wavelengths)
# advise_wide_field: (maximum_w) Maximum w 4153.6 (wavelengths)
# advise_wide_field: (diameter) Station/dish diameter 13.5 (meters)
# advise_wide_field: (primary_beam_fov) Primary beam 0.444 (rad) 25.4 (deg) 9.16e+04 (asec)
# advise_wide_field: (image_fov) Image field of view 1.33 (rad) 76.3 (deg) 2.75e+05 (asec)
# advise_wide_field: (synthesized_beam) Synthesized beam 6.3e-05 (rad) 0.00361 (deg) 13 (asec)
# advise_wide_field: (cellsize) Cellsize 1.57e-05 (rad) 0.000902 (deg) 3.25 (asec)
# advice_wide_field: (npixels) Npixels per side = 84648
# advice_wide_field: (npixels2) Npixels (power of 2) per side = 131072
# advice_wide_field: (npixels23) Npixels (power of 2, 3) per side = 98304
# advice_wide_field: (npixels_min) Npixels (power of 2, 3, 4, 5) per side = 84672
#
# advice_wide_field: (w_sampling_image) W sampling for full image = 0.1 (wavelengths)
# advice_wide_field: (w_sampling_primary_beam) W sampling for primary beam = 0.7 (wavelengths)
# advice_wide_field: (time_sampling_image) Time sampling for full image = 4.1 (s)
# advice_wide_field: (time_sampling_primary_beam) Time sampling for primary beam = 12.2 (s)
# advice_wide_field: (freq_sampling_image) Frequency sampling for full image = 2362.7 (Hz)
# advice_wide_field: (freq_sampling_primary_beam) Frequency sampling for primary beam = 7088.2 (Hz)
# advice_wide_field: (vis_slices_primary_beam) Number of planes in w stack 11511 (primary beam)
# advice_wide_field: (wprojection_planes_primary_beam) Number of planes in w projection 11511 (primary beam)
# advice_wide_field: (nwpixels_primary_beam) W support = 10224 (pixels) (primary beam)
# advice_wide_field: (vis_slices_image) Number of planes in w stack 103602 (image)
# advice_wide_field: (wprojection_planes_image) Number of planes in w projection 103602 (image)
# advice_wide_field: (nwpixels_image) W support = 276080 (pixels) (image)
# advise_wide_field: by default, using primary beam to advise on w sampling parameters
# import_image_from_fits: created >f8 image of shape (1, 1, 512, 512)
# import_image_from_fits: Max, min in ../data/SGRA_full_gt.fits = 0.624918, -0.000825
# replicate_image: replicating shape (1, 1, 512, 512) to (1, 1, 512, 512)
# /home/sunwang/radio-imaging/notebooks_and_pyscripts/helpers.py:121: ResourceWarning: unclosed file <_io.BufferedReader name='../data/SGRA_full_gt.fits'>
#   dat = fits.open(filename)[0].data

# %% [markdown]
# ### Add artificial noise, this is currently based on the source but an option should be added for it to be based on the sensitivity (https://www.skao.int/en/science-users/ska-tools/493/ska-sensitivity-calculators)

# %%
percentage = 0.02

stdv_real = numpy.std(numpy.array(vt.vis.real).flatten())
stdv_imag = numpy.std(numpy.array(vt.vis.imag).flatten())

stdv_real *= percentage
stdv_imag *= percentage

noise_real = numpy.random.normal(loc=0, scale=stdv_real, size=vt.vis.shape)
noise_imag = numpy.random.normal(loc=0, scale=stdv_imag, size=vt.vis.shape) 

noise = numpy.vectorize(complex)(noise_real, noise_imag)
vt["vis"].data = vt.vis + noise

# %% [markdown]
# ### Visualize dirty and psf and their Fourier transforms

# %%
matplotlib.rcParams['figure.figsize'] = [10, 5]

dirty, psf = dirty_psf_from_visibilities(vt,cell_size,npix=num_pix,weighting="uniform", override_cellsize=False)
helpers.plotNImages([dirty.pixels.data[0,0,:,:], psf.pixels.data[0, 0,:,:]], ["Dirty", "PSF"], cmap=cmap)

fdirty = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(numpy.fft.ifftshift(dirty.pixels.data[0,0,:,:]))))
fpsf = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(numpy.fft.ifftshift(psf.pixels.data[0,0,:,:]))))
helpers.plotNImages([fdirty ** 0.5, fpsf], ["sqrt(FDirty)", "FPSF"], cmap="turbo")
# Out:
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (56., -35.)>, starting frequency 50000000.0 Hz, and bandwidth 1000000.0 Hz
# create_image_from_visibility: uvmax = 15882.440479 wavelengths
# create_image_from_visibility: Critical cellsize = 0.000031 radians, 0.001804 degrees
# create_image_from_visibility: Cellsize = 2.83332e-05 radians, 0.00162337 degrees
# create_image_from_visibility: image shape is (1, 1, 512, 512)
# Model image plate scale (arcsec) is 5.844137e+00
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(

# %% [markdown]
# ### Plot visibility amplitudes as a function of uv radius

# %%
#vv = np.ones(vt.vis.shape)
#vt["vis"].data = vv
import math
plot_visibility([vt])
u = vt.visibility_acc.u.data
v = vt.visibility_acc.v.data

max_dist = 0

uv=vt.visibility_acc.uvw_lambda[...,0:2]
nrows,nbaselines, _ = vt.uvw.shape
uv = uv.reshape(nrows*nbaselines*len(frequencies),2)

max_dist = 0
c = numpy.zeros(nrows*nbaselines*len(frequencies))
for i, uval in enumerate(uv):
    c[i] = math.sqrt(uval[0] ** 2 + uval[1] ** 2)
    
nfreq = len(frequencies)

c = numpy.zeros((nrows, nbaselines, nfreq))
for i in range(nbaselines):
    c[:,i,:] = float(i) / nbaselines
c = numpy.imag(vt.vis.data)

# %% [markdown]
# ### Export visibility data to measurement set file

# %%
from rascil.processing_components import export_visibility_to_ms

full_ms_name = '../data7/' + gt_name + '_' + config_name + '_serial.ms'
export_visibility_to_ms(full_ms_name,[vt])

# %% [markdown]
# ## Split datasets

# %% [markdown]
# ### Obtain separation thresholds in lambda units

# %%
ell = 10
delta = 1

lambda_low = (ell + delta) / (num_pix * cell_size)
lambda_high = (ell - delta) / (num_pix * cell_size)

# %% [markdown]
# ### Load saved full dataset into casa and split it into two partitions

# %%
low_name = '../data7/' + gt_name + '_' + config_name + "_low.ms"
high_name = '../data7/' + gt_name + '_' + config_name + "_high.ms"

#I have to do things this way because for some reason importing the casatools library here crashes the notebook..
split_exec = "python split_datasets.py " + full_ms_name + " " + low_name + " " + \
    high_name + " " + str(lambda_low) + " " + str(lambda_high)

os.system(split_exec)
# Out:
# 2025-01-08 14:11:56	INFO	SubMS::parseColumnNames()	Using DATA column.
# 2025-01-08 14:11:57	INFO	SubMS::makeSelection()	443313 out of 626400 rows are going to be considered due to the selection criteria.
# 2025-01-08 14:11:59	INFO	SubMS::parseColumnNames()	Using DATA column.
# 2025-01-08 14:12:00	INFO	SubMS::makeSelection()	223059 out of 626400 rows are going to be considered due to the selection criteria.
# 0

# %% [markdown]
# ### Load short and long baseline measurement sets, plot uv coverage

# %%
from rascil.processing_components import create_visibility_from_ms

[vs] = create_visibility_from_ms(low_name)
[vl] = create_visibility_from_ms(high_name)

matplotlib.rcParams['figure.figsize'] = [6, 5]

if vs.vis.size < 1e7:
    plot_uvcoverage([vs])

if vl.vis.size < 1e7:
    plot_uvcoverage([vl])
# Out:
# create_visibility_from_ms: {'type': 'Measurement Set', 'subType': 'UVFITS', 'readme': 'This is a MeasurementSet Table holding measurements from a Telescope\nThis is a measurement set Table holding astronomical observations\n'}
# create_visibility_from_ms: Reading unique fields [0], unique data descriptions [0]
# create_visibility_from_ms: Found 443313 rows
# create_visibility_from_ms: Found 1 channels
# create_visibility_from_ms: Reading all 1 channels
# create_visibility_from_ms: Observation from 2000-01-01 18:36:23.160 to 2000-01-01 20:34:23.160
# create_visibility_from_ms: {'type': 'Measurement Set', 'subType': 'UVFITS', 'readme': 'This is a MeasurementSet Table holding measurements from a Telescope\nThis is a measurement set Table holding astronomical observations\n'}
# create_visibility_from_ms: Reading unique fields [0], unique data descriptions [0]
# create_visibility_from_ms: Found 223059 rows
# create_visibility_from_ms: Found 1 channels
# create_visibility_from_ms: Reading all 1 channels
# create_visibility_from_ms: Observation from 2000-01-01 18:36:23.160 to 2000-01-01 20:34:23.160
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:87: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'baselines' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   super().__init__(data_vars, coords=coords, attrs=attrs)
# There is no flagged visibility. Skip plotting flagged.
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:87: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'baselines' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   super().__init__(data_vars, coords=coords, attrs=attrs)
# /home/sunwang/.local/lib/python3.10/site-packages/xarray/core/dataarray.py:3099: DeprecationWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'baselines'} to avoid an error in the future.
#   ds = self._to_temp_dataset().drop_vars(names, errors=errors)
# There is no flagged visibility. Skip plotting flagged.
# /home/sunwang/.local/lib/python3.10/site-packages/xarray/core/dataarray.py:3099: DeprecationWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'baselines'} to avoid an error in the future.
#   ds = self._to_temp_dataset().drop_vars(names, errors=errors)

# %%
matplotlib.rcParams['figure.figsize'] = [10, 5]

dirty_short, psf_short = dirty_psf_from_visibilities(vs,cell_size,npix=512,weighting="uniform")
helpers.plotNImages([dirty_short.pixels.data[0,0,:,:], psf_short.pixels.data[0, 0,:,:]], ["Dirty short", "PSF short"], cmap=cmap)

fdirty_short = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(numpy.fft.ifftshift(dirty_short.pixels.data[0,0,:,:]))))
fpsf_short = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(numpy.fft.ifftshift(psf_short.pixels.data[0,0,:,:]))))
helpers.plotNImages([fdirty_short ** 0.5, fpsf_short], ["sqrt(FDirty short)", "FPSF short"], cmap="turbo")
# Out:
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (56., -35.)>, starting frequency 50000000.0 Hz, and bandwidth 1000000.0 Hz
# create_image_from_visibility: uvmax = 757.660254 wavelengths
# create_image_from_visibility: Critical cellsize = 0.000660 radians, 0.037811 degrees
# create_image_from_visibility: Cellsize = 2.83332e-05 radians, 0.00162337 degrees
# create_image_from_visibility: image shape is (1, 1, 512, 512)
# Model image plate scale (arcsec) is 5.844137e+00
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(

# %%
dirty_long, psf_long = dirty_psf_from_visibilities(vl,cell_size,npix=512,weighting="uniform")
helpers.plotNImages([dirty_long.pixels.data[0,0,:,:], psf_long.pixels.data[0, 0,:,:]], ["Dirty short", "PSF short"], cmap=cmap)

fdirty_long = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(numpy.fft.ifftshift(dirty_long.pixels.data[0,0,:,:]))))
fpsf_long = numpy.abs(numpy.fft.fftshift(numpy.fft.fft2(numpy.fft.ifftshift(psf_long.pixels.data[0,0,:,:]))))
helpers.plotNImages([fdirty_long ** 0.5, fpsf_long], ["sqrt(FDirty long)", "FPSF long"], cmap="turbo")
# Out:
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (56., -35.)>, starting frequency 50000000.0 Hz, and bandwidth 1000000.0 Hz
# create_image_from_visibility: uvmax = 15882.440479 wavelengths
# create_image_from_visibility: Critical cellsize = 0.000031 radians, 0.001804 degrees
# create_image_from_visibility: Cellsize = 2.83332e-05 radians, 0.00162337 degrees
# create_image_from_visibility: image shape is (1, 1, 512, 512)
# Model image plate scale (arcsec) is 5.844137e+00
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:452: DeprecationWarning: flagged_imaging_weight is deprecated, please use flagged_weight instead
#   warnings.warn(
# /home/sunwang/.local/lib/python3.10/site-packages/ska_sdp_datamodels/visibility/vis_model.py:201: DeprecationWarning: imaging_weight is deprecated, please use weight instead
#   warnings.warn(

# %% [markdown]
# ### Partitions and full dataset compared in a grid

# %%
#show_image(im,cm=cmap)
#show_image(dirty,cm=cmap)
#show_image(psf,cm=cmap)
fig = plt.figure(figsize=(12,3))
ax=fig.add_subplot(1,3,1,projection=im.image_acc.wcs.sub([1, 2]))
ax.imshow(im.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(im.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(im.image_acc.wcs.wcs.ctype[1])

ax=fig.add_subplot(1,3,2,projection=dirty.image_acc.wcs.sub([1, 2]))
ax.imshow(dirty.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(dirty.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(dirty.image_acc.wcs.wcs.ctype[1])

ax=fig.add_subplot(1,3,3,projection=psf.image_acc.wcs.sub([1, 2]))
ax.imshow(psf.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(psf.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(psf.image_acc.wcs.wcs.ctype[1])

# Now for short baselines only
fig = plt.figure(figsize=(12,3))
ax=fig.add_subplot(1,3,1,projection=im.image_acc.wcs.sub([1, 2]))
ax.imshow(im.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(im.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(im.image_acc.wcs.wcs.ctype[1])

ax=fig.add_subplot(1,3,2,projection=dirty_short.image_acc.wcs.sub([1, 2]))
ax.imshow(dirty_short.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(dirty_short.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(dirty_short.image_acc.wcs.wcs.ctype[1])

ax=fig.add_subplot(1,3,3,projection=psf_short.image_acc.wcs.sub([1, 2]))
ax.imshow(psf_short.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(psf_short.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(psf_short.image_acc.wcs.wcs.ctype[1])

# Now for long baselines only
fig = plt.figure(figsize=(12,3))
ax=fig.add_subplot(1,3,1,projection=im.image_acc.wcs.sub([1, 2]))
ax.imshow(im.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(im.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(im.image_acc.wcs.wcs.ctype[1])

ax=fig.add_subplot(1,3,2,projection=dirty_long.image_acc.wcs.sub([1, 2]))
ax.imshow(dirty_long.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(dirty_long.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(dirty_long.image_acc.wcs.wcs.ctype[1])

ax=fig.add_subplot(1,3,3,projection=psf_long.image_acc.wcs.sub([1, 2]))
ax.imshow(psf_long.pixels.data[0,0,:,:],origin='lower',cmap=cmap)
ax.set_xlabel(psf_long.image_acc.wcs.wcs.ctype[0])
ax.set_ylabel(psf_long.image_acc.wcs.wcs.ctype[1])

# %% [markdown]
# ### Export dirty, psf to fits

# %%
# Export dirty, psf
dirty.image_acc.export_to_fits('../data7/' + gt_name + '_dirty.fits')
psf.image_acc.export_to_fits('../data7/'  + gt_name + '_psf.fits')

# %% [markdown]
# ### Comparison of PSF Shapes

# %%
size = 200

plt.plot(psf['pixels'].data[0,0,256,:],label='all baselines')
plt.plot(psf_short['pixels'].data[0,0,256,:],label='short baselines')
plt.plot(psf_long['pixels'].data[0,0,256,:],label='long baselines')
plt.legend()
plt.title('Point spread function cuts')
plt.xlim((256 - size, 256 + size)); plt.ylim((-0.2,1.1))
# Out:
# (-0.2, 1.1)
